# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import pandas as pd
import datetime
import calendar
import time
import numpy as np
import time
import nltk
from nltk.corpus import stopwords
from collections import Counter
import json
import ast
import math

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gauth\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#COMPLETE TAG EXTRACTOR
tagSet=set()
for pageNo in range(1,94):  #No. of pages 1 to 93
  my_url='https://askubuntu.com/tags?page='+str(pageNo)+'&tab=name'
  uClient=uReq(my_url)
  page_html=uClient.read()
  uClient.close()
  page_soup=soup(page_html,"html.parser")
  question_summary=page_soup.findAll("a",{"class":"post-tag"})
 
  for tagNoInPage in range (len(question_summary)):
    tag=re.findall(r'>.*</a>',str(question_summary[tagNoInPage]))
    temp=str(tag[0]).replace(">","").replace("</a","")
    #print(temp)
    tagSet.add(temp)

# %%
for i in (tagSet):  #was 3276
    print(i)
# Out:
# kwin
# file-command
# xls
# slowmovideo
# ruby-on-rails
# apt
# configuration
# crossover-office
# sound-theme
# sql
# qmail
# software-sources
# postgresql-8.4
# hevc
# send2printer
# gwibber
# usb-modeswitch
# dell
# home
# freespeak
# mailutils
# ssh-import-id
# go
# minimize
# man
# vodafone
# pgp
# zte
# idevices
# btrfs
# uds
# logging
# initramfs
# android-studio
# ascii-art
# setcap
# webapps
# pyside
# ubuntu13.04
# directory
# mozilla
# impress
# heat
# signature
# svg
# screenlets
# cmd
# rename
# downloaders
# key-binding
# multipointerx
# permissions
# i915
# opencv
# tor-browser
# hdparm
# software-uninstall
# temperature
# picasa
# emerald
# syntax
# driver
# encfs
# snap-package
# ubuntu
# serial-port
# video-recording
# live-cd
# docking
# less
# xfce
# locate
# www
# multi-core
# indexing
# bandwidth
# dlna
# boot-repair
# woeusb
# iball
# x11-forwarding
# kdevelop
# .sh
# 14.04.4
# ubuntu-advantage
# chrome-extension
# free
# systray
# thunar
# display-rotation
# translation
# indicator-syc
# chromeos
# nitro
# services
# sha256
# amazon
# hdtv
# libinput
# html
# rodbc
# naming-conventions
# firewalld
# nis
# bamboo
# busybox
# smart
# gnash
# paint
# radius
# vivaldi
# whoopsie
# cairo
# clutter
# netplan
# uniq
# deluge
# testing
# ubuntu-netbook
# canopy
# home-directory
# ivybridge
# x230
# 18.04.01
# metacity
# chown
# emacs
# c++
# reset
# hostap
# amdgpu-pro
# tooltip
# user-accounts
# trim
# lightread
# minicom
# noise
# stress-testing
# username
# qt3
# media-buttons
# xubuntu-desktop
# inxi
# kde-connect
# hebrew
# .desktop
# disk-management
# pci
# scribus
# partition
# amd-processor
# ubuntu-emulator
# dpi
# editor
# logitech
# snappy
# compiz
# autokey
# ardour
# samba
# virtualization
# theme
# camera
# irc
# character-set
# f.lux
# text-to-speech
# word-processor
# hplip
# grab-handles
# dvd-audio
# lxc
# resume
# postfix
# startup
# asus
# debugging
# gpodder
# bluegriffon
# intel-atom
# borders
# libpcap
# messaging-menu
# wallpaper
# webapp-development
# extension
# filezilla
# sector-size
# sources.list
# static-ip
# rsnapshot
# routing
# widgets
# pcie
# binutils
# lxqt
# switch-user
# orchestra
# cmus
# boot-order
# adobe
# sony
# adduser
# updates
# porting-ubuntu-touch
# usbfs
# 11.10
# gdm
# searchmonkey
# glassfish
# keycodes
# aws
# bison
# geoip
# ossec
# apple-keyboard
# prism
# apf
# restricted-formats
# preload
# ubuntu-pay
# csd
# laravel
# hotot
# ubuntu-one-api
# lightworks
# logwatch
# system-installation
# top
# root
# korganizer
# history
# duplicate-files
# reiserfs
# remastersys
# franz
# grub
# qgis
# ksh
# remote-access
# foomatic
# chsh
# nvidia-geforce
# gnuplot
# gprename
# motu
# cgi
# shebang
# ibm
# mate
# smartscopes
# ubuntu-wiki
# time
# decompression
# pdfgrep
# intel-hd
# dvorak
# rails
# gems
# gdebi
# icedtea
# wireshark
# gnome-open
# overscan
# kylin
# vga
# monitor-calibration
# game
# nessus
# presario
# hosts
# integrated
# ssh
# kodi
# pidgin
# bfq
# libreoffice-calc
# startup-disk-creator
# digitalpen
# quicklists
# parted
# krita
# mongodb
# libgcrypt
# zenity
# jekyll
# scrypt
# ibus-avro
# ivtv
# framerate
# hamster
# kickoff
# stream
# zsh
# paste
# ip-scanner
# trusty
# vpnc
# recovery
# icewm
# safely
# unity-control-center
# subpixel-rendering
# rclone
# awn
# function-keys
# x2go
# xubuntu
# wav
# pdf-bookmarks
# at-command
# mobi
# mousepad
# soft-link
# switchbox
# systemback
# gnome-settings-daemon
# ralink
# tagging
# 19.04
# matlab
# lshw
# bugzilla
# chcon
# azure
# redmine
# software-center
# torrent
# backup
# login-screen
# alternate
# my-weather-indicator
# kile
# google-chrome
# nextcloud
# ubuntu-edge
# ansi
# wpa-supplicant
# unity-web-player
# data-recovery
# freebasic
# headless
# kde
# wired
# openshot
# 18.10
# apparmor
# plugin
# mpv-media-player
# aquaris
# tether
# macbook
# copy.com
# font-rendering
# info
# cdma
# environment
# automatic
# certificates
# hal
# jdk
# supervisor
# ibm-lotus-symphony
# nice
# sound-blaster
# ipv6
# tomboy
# macbook-air
# powerpc
# crebs
# ubuntu-netbook-remix
# tls
# 10.04
# clipboard-manager
# debuild
# clone
# udisks
# convert
# color-management
# removal
# flatpak
# scripting
# xp
# focaltech
# scanning
# yumi
# utorrent
# python-2.7
# edubuntu
# utopic
# vps
# email-client
# 7zip
# fsck
# unknown-device
# livedvd
# 12.04.3
# delete
# crossover
# toshiba-satellite
# tor
# transfer
# notify-send
# pcmanfm
# legal
# apt-cacher
# paid-applications
# pagestack
# scsi
# focus
# mathematica
# qt
# flac
# xfce4
# xml
# utc-time
# zip
# gigolo
# timeout
# 16.04
# cups-lpd
# console-kit
# governor
# mpd
# windows-8
# dash
# logs
# caffe
# winxp
# privacy
# cli
# whisker
# imap
# keyboard-backlight
# elasticsearch
# xterm
# fat32
# gateway
# nethogs
# privileges
# freeze
# systemd-journald
# pam
# ubuntu-core
# openbabel
# runlevel
# annotation
# hostname
# rtl8723be
# kmail
# luz
# windows-xp
# ie
# office365
# ubuntu-one-windows
# konica
# spdif
# font-converter
# design
# web-feed
# database
# mencoder
# user-mode-linux
# faenza
# shutter
# git-buildpackage
# vm
# xps-file
# ghostscript
# smb
# colemak
# htdocs
# gmrun
# patch
# fastcgi
# mov
# shumway
# spotify
# wacom
# distro-recommendation
# file-format
# mercurial
# layout
# flash
# refit
# abcde
# backport
# lm-sensors
# autofs
# cve
# scale-mode
# systemd
# xfce4-terminal
# libpurple
# port-forwarding
# 2d
# pyqt
# jre
# menu-bar
# raring
# steam
# ath5k
# gnote
# snapshot
# symbolic-link
# setup
# license
# xmms
# kms
# vi
# bsd
# vala
# sansa-clip
# rabbitmq
# tearing
# devilspie
# internet-radio
# arp
# fluendo
# card-reader
# nvidia-optimus
# centrino
# lockup
# popcon
# rutorrent
# xmpp
# activities-overview
# radiance
# firefox-extensions
# chorded-keyboard
# customization
# tmux
# genymotion
# mailing-list
# wireless
# mingw32
# mbr
# windows-active-directory
# scheduler
# openarena
# umask
# zlib
# meego
# vmplayer
# esx
# search
# tsclient
# hard-link
# websocket
# pysdm
# ram
# bootloader
# nautilus
# anjuta
# nomodeset
# 12.04
# flask
# uget
# gpu
# k3b
# monitor
# libertas
# free-software
# e1000
# multiple-monitors
# openldap
# hp-cloud
# pstree
# opal-2.0
# lyx
# systemd-networkd
# synapse
# boot-screen
# brotli
# cad
# gnome-disk-utility
# jmol
# madwifi
# nokia
# c#
# restart
# dyndns
# winetricks
# quicktime
# adobe-digital-editions
# grive
# bomi
# blacklist
# libunity
# motion
# jboss
# multimedia
# partial-upgrade
# aif
# image-viewer
# theme-development
# nexus-7
# uninstall
# deadlock
# mplayer
# virtualgl
# workspaces
# posix-compliant
# synaptics
# transmission
# muon-package-manager
# xkb
# intel
# cardapio
# malware
# offline
# os-prober
# connections
# unattended-upgrades
# flashplugin-nonfree
# diagram
# bind
# flashcache
# overlay-scrollbars
# virtualhost
# xdelta
# udf
# zimbra
# adblock
# dsl
# installed-programs
# wmv
# uml
# multiarch
# updatedb
# delicious
# dependency
# icecat
# assembler
# crashes
# xerox
# desktop-apps
# mendeley
# upgrading
# gaming
# tabs
# cgminer
# hybrid
# microsoft-powerpoint
# tree
# juju
# light-locker
# realtek-wireless
# gnome-keyring
# xmodmap
# installing
# 64-bit
# 15.10
# hddtemp
# ubuntu-minimal
# file-size
# razorqt
# ascii
# language-support
# redshift
# package
# pavucontrol
# ubuntu-font-family
# update-manager
# dock
# error-handling
# terminal-server
# dh-make
# nat64
# package-info
# essid
# reverse-tethering
# zsnes
# tcsh
# thumbnails
# intallation
# 464xlat
# client
# continuous-deployment
# fhs
# smbus
# ssl
# tomcat
# glibc
# xmonad
# drivel
# sane
# gnu-screen
# vinagre
# color-depth
# qtwebkit
# elinks
# autostart
# password
# testdisk
# pipe
# vifm
# vmware-view
# icaclient
# xdg
# asus-pc
# functions
# ubuntu-dock
# moksha
# bluefish
# commands
# ubuntu-email-address
# kazam
# alternative
# pm-utils
# zram
# java
# proprietary
# performance
# lyrics
# overclocking
# google-app-engine
# du
# shared-folders
# framebuffer
# setxkbdmap
# find-command
# hd6470m
# writer
# v-ram
# wayland
# applications-lens
# via
# bookmarks
# randr
# xhci-hcd
# protocol
# relinux
# unicode
# window-management
# samba4
# dualhead
# xrandr
# custom-installer
# 0ad
# cross-compilation
# mac-mini
# kdm
# poulsbo
# ahci
# vsftp
# gnome-panel
# bash
# systemd-logind
# brainstorm
# chm2pdf
# gammu
# debconf
# scanner
# disk
# html5
# oneiric
# home-server
# download
# wakeup
# sudo
# vpn
# photorec
# cryptroot
# cluster
# google-reader
# viruses
# cfq
# contributing
# desktop-environments
# voice-recognition
# cyrillic
# audio-recording
# unity-dash
# office-communicator
# mediaserver
# npm
# memory-usage
# remove
# upstream
# ices
# darktable
# indicator
# unison
# nvidia-settings
# remote-assistance
# adobe-reader
# aview
# xserver
# coreutils
# metadata
# mysql-workbench
# vmbuilder
# cms
# 18.04.1
# jpilot
# moodle
# system-monitor
# sensors
# gsettings
# print-screen
# xkill
# statistical
# avi
# openoffice.org
# reboot
# gnutls
# fps
# user-space
# backintime
# variety
# ups
# cd
# processor
# rtmp
# unallocated
# file-server
# xampp
# windows-phone
# brother
# reverse-proxy
# dialog
# netgear
# csm
# vmd
# typing-break
# jar
# nm-applet
# gnome-pie
# phonon
# shuttle
# ethereum
# cd-image
# mkdir
# workrave
# ruby
# pppoe
# rsyslog
# xvfb
# server
# charms
# guvcview
# task-management
# x11rdp
# numlock
# connman
# pcscd
# elementary-theme
# ccsm
# ureadahead
# xinetd
# empathy
# auto-login
# benchmarks
# mode
# terminal
# notification
# screenshot
# mdns
# yubikey
# rss
# netflix-desktop
# vmware-player
# groups
# lsb-release
# software-updater
# duplicate
# indicator-session
# vimrc
# output
# bottle
# telemetry
# inkscape
# shortcut-keys
# lintian
# meizu-mx4
# shotwell
# terminal-bell
# wingpanel
# backuppc
# intranet
# folder
# kolourpaint
# single-sign-on
# trace32
# zombie
# chromecast
# email
# pssh
# nvidia-current
# media-library
# geany
# 4k-monitor
# couchdb
# crash
# opt
# lmms
# coreboot
# certification
# bluetooth-speaker
# pim
# policy
# aircrack-ng
# session
# nemo
# tvtime
# visual-studio-code
# wallch
# sudoers
# incron
# dvb
# kubuntu-netbook
# click-packages
# passwords
# cmatrix
# foreman
# pictbridge
# application-review-board
# ncmpcpp
# crashplan
# memory-leak
# rpm
# changelog
# .deb
# apport
# daily-build
# music-player
# haproxy
# privman
# vdpau
# ms-exchange
# power-management
# medibuntu
# suspend
# zathura
# screencast
# arduino
# tkinter
# pkg-config
# freenx
# libreoffice
# preferences
# prompt
# virtual-console
# firestarter
# hostapd
# manpage
# mdm
# mp3-player
# bzr
# matrox
# phpbb
# syntax-highlighting
# amd-ryzen
# maven-3
# kali-linux-tools
# unity8
# axel
# kvm
# tcp-ip
# xchat
# 8.04
# multipath
# spindown
# gamepad
# kaddressbook
# filemanager
# jabber
# visualization
# secure-erase
# titlebar-buttons
# letsencrypt
# drive
# mirrors
# apt-fast
# versions
# photo-editing
# network-bridge
# nvidia-current-dev
# ayatana
# macbook-pro
# pascal
# webm
# attachment
# mozc
# screensaver
# avahi
# architecture
# octave
# scrollbar
# thinkpad
# uefi
# fedena
# screen
# xonsh
# raspberrypi
# gnome-color-manager
# displaylink
# mdadm
# qml
# xorg
# contacts
# epiphany
# localization
# tomcat6
# switchable-graphics
# resolv.conf
# vst
# utf-8
# ubiquity
# wine
# file-extension
# krusader
# ubuntu-12.04
# frequency
# nohup
# grub-efi
# ps1
# training
# 14.04
# boinc
# exfat
# zfs
# wmctrl
# aptana-studio
# administration
# xfs
# rfkill
# swapfile
# fingerprint-reader
# traffic
# conversion
# gnome-schedule
# caldav
# packages
# simon
# remmina
# tox
# tinyos
# ideapad
# dansguardian
# lock
# chmsee
# compile
# precise-pangolin
# ntop
# gdb
# ubuntu-light
# covergloobus
# ppa
# iowait
# apt-mirror
# intel-graphics
# unity-next
# volume-control
# fullscreen
# contrast
# nvidia
# windows-vista
# power
# nftables
# calculator
# pinning
# home-theatre
# version-upgrade
# binary
# snmp
# images
# lame
# trackpad
# midori
# pip
# standby
# memtest
# filesystem
# openerp
# nvidia-prime
# podcast
# powertop
# release
# yaboot
# chemaxon
# ubuntu-phone
# gthumb
# wvdial
# libdbusmenu
# aac
# htop
# notify-osd
# unclutter
# localrepository
# m10
# tracker
# ovirt
# rdp
# sopcast
# 4g
# matplotlib
# oauth
# exaile
# hacking
# b43
# sata
# multisystem
# dm-cache
# adobe-air
# netbeans
# nimbuzz
# pager
# gpl
# zabbix
# guest-additions
# md5sum
# amd-graphics
# phone
# vino
# ppc64le
# katoolin
# python
# tmpfs
# software-installation
# apt-get
# exiftool
# chmod
# icon-themes
# red5
# xdg-base-directory
# kali
# xinit
# bbswitch
# keychain
# music
# apache
# chroot
# eps
# laserjet
# xargs
# checksums
# nagios3
# pxe
# user-management
# font
# gnome-software
# clion
# websites
# wicd
# localhost
# blueman
# filelink
# cinnamon
# source-packages
# sort
# tp-link
# firefox-4
# openconnect
# minecraft
# openbox
# xinput
# command-line-tools
# persistent
# virtual-machine
# multiple-users
# network-drive
# gnome-builder
# afs
# ldap
# packaging
# macosx
# chkrootkit
# file-sharing
# folders
# irda
# case-insensitive
# tp-smapi
# bfs
# vulkan
# xprop
# document-management
# 16.10
# proposed-updates
# cron-jobs
# stdout
# qt5
# gma500
# mouse-scroll
# unreadable
# boot-to-ram
# sockets
# ogg-opus
# ufs
# fbgrab
# cubieboard
# composer
# ssd
# ubuntu-15.10
# geolocation
# bug-reporting
# ocr
# dconf
# mail
# zsync
# ext3
# touchscreen
# shopping-lens
# 9.04
# vim
# sshpass
# promotion
# usability
# menulibre
# parental-controls
# diff
# ubuntu-touch
# resize
# conky
# flv
# 14.04.x
# modprobe
# webserver
# tag
# nouveau
# compiler
# d-link
# scaling
# resolvconf
# directories
# rtsp
# barcode
# show-desktop
# tcl
# poweroff
# bionic
# lisp
# pstn
# hdmi
# cyrus
# crimson
# bleachbit
# panel
# sleep
# cryptkeeper
# google-maps
# radeon
# chef
# drupal
# maverick
# beta
# etc
# connection
# thunar-custom-actions
# pptpd
# opencl
# gambas3
# locales
# joystick
# previews
# ultrabook
# web-development
# subnet
# process-priority
# imagemagick
# ubuntu-drivers
# ux
# squid3
# vim-plugin
# japanese
# cybercafe
# deb
# zoom
# idle
# javafx
# fontconfig
# logrotate
# mouse-pointer
# panorama
# bazaar
# dvb-t
# kdenlive
# lynx
# grsync
# finance
# sagemath
# silverlight
# cloudera-manager
# cryptswap
# bumblebee
# socks5
# vista
# sssd
# eclipse-cdt
# sysrq
# iscsi
# netbook-edition
# clonezilla
# debmirror
# enlightenment
# special-characters
# espeak
# freemat
# lense
# ubuntu-mate
# plasma
# locally-integrated-menus
# xen
# sound-recorder
# libre.fm
# rescue-mode
# kwallet
# tasksel
# ubuntu-software-center
# development
# sylpheed
# greybird
# quodlibet
# cisco
# tint2
# minix
# lirc-zilog
# tr
# testsuite
# network-manager
# airplay
# onboard
# desktopcouch
# gestures
# wodim
# squid-deb-proxy
# amazon-mp3-downloader
# jungledisk
# splash
# gnome-maps
# microsoft-mouse
# airplane-mode
# compat-wireless
# fatrat
# grep
# source
# msgfmt
# ltsp
# anacron
# pinta
# merge
# system-wide
# key-combination
# networking
# keyserver
# alps
# microsoft-lync
# space
# fdisk
# anbox
# microsoft-office
# amarok
# speech-recognition
# burning
# arista-transcoder
# microsoft-word
# gerbera
# boot-failure
# radio
# instagram
# static-linking
# avconv
# gphoto2
# wildcards
# httrack
# sync
# user-profile
# linux-headers
# xcalib
# image-editor
# caffeine
# vgaswitcheroo
# gnome-clocks
# system-info
# lightning
# support
# ubuntu-tv
# metapackages
# additional-drivers
# scite
# a2dp
# gmail
# golang
# useradd
# jailkit
# optimization
# xcompmgr
# bcache
# gnome2
# configure
# multiboot
# thunderbolt
# wifi-direct
# gnome-classic
# dual-graphics
# multiseat
# apturl
# apache-ant
# pbuilder
# splash-screen
# hardware-enablement-stack
# xilinx
# mod-ssl
# sdl
# twinkle
# cake
# synergy
# ip-forward
# wpa
# gcc
# bittorrent
# rust
# chromebook
# ubuntu-sdk
# system
# grails
# jupyter
# key-bindings
# netinstall
# usb-modem
# f2fs
# ros
# easytether
# location-bar
# network-monitoring
# beatbox
# xbindkeys
# shadow
# ftp
# gnome-screenshot
# nautilus-elementary
# digikam
# security
# ios
# mogrify
# enhanceio
# mute
# pixma
# firefox
# web-design
# virtualenvwrapper
# openswan
# postscript
# ecryptfs
# flash-plugin
# flareget
# doubleclick
# hardy
# weston
# iphone
# remapping
# storage
# lazarus
# haskell
# plex
# replaygain
# icons
# ipmi
# aptitude
# electron
# education
# software-boutique
# okular
# nfc
# quickly
# gamma
# idm
# nat
# vbox
# bootup
# kmymoney
# pcloud
# undelete
# pango
# xdmcp
# git-ubuntu
# transliteration
# internet-connection
# calibre
# cursor
# proftpd
# airmon-ng
# locoteams
# pygi
# fglrx
# appindicator
# keryx
# php7
# qupzilla
# ssmtp
# unity-launcher-api
# zend
# appimage
# eeepc
# fvwm
# grub4dos
# mouse
# ultrastar-deluxe
# blog
# emoji
# partitioning
# jhbuild
# png
# unity-tweak-tool
# conda
# vlc
# autoconf
# gzip
# bzip2
# adobe-kuler
# davmail
# flicker
# kopete
# pcsx2
# qmake
# clamav
# pentesting
# insync
# libreoffice-writer
# polkit
# booting
# lvmcache
# amd64
# epson
# repositories
# intel-wireless
# webex
# wheel
# wunderlist
# julia-lang
# vagrant
# reviews
# antivirus
# desktop-recording
# xbox-360
# eric
# 14.10
# files
# bitnami
# php5
# webco
# kubuntu
# inetd
# killall
# vsftpd
# download-manager
# gnucash
# productivity
# macbuntu
# unity-greeter
# acpi
# gufw
# korean
# nautilus-extensions
# code-blocks
# vuze
# crunchbang
# canonical-livepatch
# mupdf
# cpulimit
# pianobar
# g++
# xset
# default
# ssh-agent
# minitube
# virtual-printer
# launchy
# pihole
# smtp
# dell-studio-xps-16
# midnight-commander
# photography
# scikit-learn
# acpid
# audible
# plank
# sendmail
# awesome
# m2
# 17.10
# upload
# meld
# nut
# doc
# linphone
# fancontrol
# neofetch
# polipo
# gmplayer
# htc
# libvirt
# ltsp-client
# bash-history
# luks
# multiple-workstations
# tv
# redirect
# version-control
# presentation
# sysfs
# installation-failure
# word-documents
# standalone-session
# organizer
# whois
# nrpe
# nagios
# libraries
# mega
# default-programs
# shortcuts-keys
# fax
# cheese
# kernel-modules
# mbox
# bashrc
# asterisk
# branding
# mount
# xfce-panel
# mms
# tensorflow
# memcached
# curlftpfs
# libreoffice-impress
# mac
# alcatel
# responsiveness
# hidden-files
# adobe-acrobat
# keyboard-shortcuts
# kernel-option
# ocelot
# multiverse
# parallels
# single-user
# tilda
# join
# ns2
# pinyin
# autossh
# batch
# community
# ppp
# graphics-tablet
# wireless-access-point
# numpad
# oneconf
# pulseaudio
# gtk3
# virtualbox-networking
# ap-hotspot
# fstab
# cairo-dock
# github
# history-of-ubuntu
# midi
# pptp
# grooveshark
# ipad
# ubuntu-forums
# musescore
# plugins
# pendrive
# solaris
# downgrade
# deja-dup
# style
# themes
# wlan
# p2p
# fortune
# iwlwifi
# ulimit
# a11y
# runit
# owncloud-client
# dynamic-linking
# dockstation
# tools
# ndb
# sound-problem
# easybcd
# recommendations
# ubuntu-gnome
# rights
# displayport
# pkexec
# snap
# deadbeef
# doublecmd
# books
# realtime
# unr
# automake
# json
# boot-time
# i3-wm
# ocs-inventory-ng
# hdd
# google-plus
# pae
# dovecot
# daemon
# openssh
# master-pdf-editor
# lts
# find
# online-storage
# unity-launcher
# documentation
# knr
# memory-card
# blu-ray
# adt
# lastpass
# tuxguitar
# mib
# keyboard-accelerators
# poster
# wordpress
# quality-assurance
# amixer
# gnome
# postgresql
# video-capture-card
# phpmyadmin
# kernel
# dhclient
# application-development
# stickynotes
# cp
# m4a
# background-process
# samsung
# 12.04.1
# kinect
# gnome-calculator
# production
# brightness
# urban-terror
# nautilus-actions
# grsec
# mountpoint
# glib
# scala
# gloobus-preview
# script
# xclip
# vlc-player
# xsane
# guest-session
# accounts
# add-on
# kate
# animations
# povray
# effects
# fog
# ath9k
# awk
# lightdm
# printing
# telepathy
# flickr
# landscape
# ncal
# upgrade
# hardware-test
# streaming
# indicator-message
# loop-device
# pipenv
# chess
# qbittorrent
# colors
# dell-vostro
# scrolling
# lxterminal
# applications-menu
# guest-os
# texlive
# printer-driver
# video4linux
# mixxx
# rsync
# csh
# signal
# logo
# google
# ushare
# version
# livecd
# terminology
# dell-mini-10
# numix
# gnome-shell-extension
# 7.10
# alien
# squid
# xulrunner
# dmidecode
# hosting
# ash
# fedora
# package-management
# lenses
# tomcat7
# rygel
# sbuild
# display
# apple
# mail-server
# linaro
# ubuntu-restricted-extras
# file-association
# ifconfig
# vmdk
# 11.04
# osx
# login
# favorites
# dia
# gnome-flashback
# multiwriter
# lg
# spell-checking
# fujitsu-siemens
# uvc
# unicorn
# mv-command
# cryptsetup
# logitech-unifying
# poppler
# appmenu
# drag-and-drop
# openvas
# soundcard
# sound-juicer
# remote-desktop
# default-browser
# f-spot
# rosegarden
# touch
# clementine
# timezone
# umount
# vidalia
# firewall
# gps
# format-conversion
# lampp
# lincroft
# sdk
# microsoft-installer
# 12.04lts
# date
# gvim
# media-manager
# recovery-mode
# secure-delete
# gnome-session
# nexus-5x
# artwork
# rockbox
# startupmanager
# google-hangouts
# windows-10
# acer
# photo
# fabric
# fan
# persistence
# xinerama
# csv
# ricoh
# google-picasa
# latex
# wpa2
# evernote
# micro-sd
# disconnect
# sis-graphics
# cd-ripping
# glade
# puppetmaster
# software-recommendation
# inotify
# atime
# cdn
# shellcheck
# dash-shell
# lock-screen
# monitoring
# seamonkey
# xps
# overheating
# build
# jenkins
# hardware
# bonjour
# disk-check
# graphite
# duplex-printing
# pepperflash
# xorg-edgers
# nvme
# taskbar
# compositing
# dd-wrt
# cifs
# dvi
# boot-partition
# systemd-timesyncd
# ceph
# webmin
# oneric
# peripherals
# gnome-fallback
# openvz
# xine
# mail-notification
# stylus
# opendns
# window-placement
# cpan
# xte
# handbrake
# xbmc
# bitcoin
# ndiswrapper
# system-call-fastboot
# window-decoration
# docker
# gpg
# mta
# keepass
# interface
# subliminal
# cups
# oss-sound-system
# isolinux
# boost
# openstack
# scheme
# rootkit
# suspend-resume
# restricted-access
# dhcpv6
# intel-cpu
# tap-to-click
# hd-video
# facebook
# libtiff
# tcpdump
# lexmark
# location
# seahorse
# veracrypt
# hadoop
# gnome-boxes
# console
# schedule
# gnome-dash
# vt-x
# remote-control
# time-management
# epub
# lxdm
# ps
# freelan
# mythtv
# context-menu
# dolphin
# devices
# xfwm4
# telegram
# addon
# cache
# odbc
# mutter
# spice
# dependencies
# caja
# metasploit
# su
# zeitgeist
# 10.10
# language
# who
# apache2.4
# inspiron
# ext4
# domain-server
# ksnapshot
# cuttlefish
# sound
# bq
# youtube
# secure-boot
# ubuntu-for-phones
# reprepro
# cassandra
# playlists
# jpeg
# oracle
# display-manager
# trash
# beowulf
# php5-fpm
# gnupg
# i18n
# gallium
# windicators
# cream
# mythbuntu
# iso
# recordmydesktop
# one-hundred-paper-cuts
# lua
# detect
# konsole
# musicbrainz
# galaxy-nexus
# quantum
# rtl8192ce
# xdotool
# nginx
# teamviewer
# vncviewer
# cookie
# kvm-switch
# pygtk
# solr
# moonlight
# gui
# javascript
# passwd
# nexus-4
# watch-command
# video-driver
# launchpad-api
# dual-boot
# autotools
# photoshop
# raid
# pipelight
# recoll
# rtl8192cu
# compose-key
# copy
# yahoo
# mirantis
# xbox-one
# pure-ftpd
# gpt
# ati
# plot
# slack
# floppy
# aptdaemon
# openjdk
# https
# rabbitvcs
# libxml
# snapcraft
# sound-editor
# gis
# wget
# resolution
# apticron
# app-install
# unix
# text
# df
# log
# workgroup
# netstat
# ubuntu14.04
# add-apt-repository
# gksu
# netflix
# cedarview
# fuse
# 32-bit
# 13.04
# msn
# usb-installation
# panel-applets
# portscan
# jigdo
# rm
# headphones
# gdevilspie
# .htaccess
# alacarte
# uck
# headset
# mass-storage
# cd-command
# tuxonice
# messaging-tray
# rev
# cloud
# reinstall
# syslinux
# shareit
# lxde
# paths
# fwupd
# kubernetes
# android-emulator
# autorun
# video-editor
# kde5
# visual-artifacts
# plexmediaserver
# live-usb
# top-bar
# mediatek
# external-soundcard
# netcat
# 12.04.5
# objective-c
# php-5.4
# scapy
# vnc
# icon
# everpad
# maintenance
# openssl
# uid
# system-settings
# wekan
# djvu
# events
# neatx
# commercial
# iptables
# ubufox
# wwan
# mutt
# command
# synchronize
# lenovo
# ambiance
# smartphone
# bootchart
# charset
# emblem
# quality
# ld
# hash
# sms
# akonadi
# shellshock
# crossplatform
# release-management
# cmyk
# owncloud-server
# pencil
# memory
# checkinstall
# purchase
# statusbar
# online-accounts
# iconv
# mp3-tag
# virtualenv
# time-command
# gksudo
# joomla
# firefox-nightly
# pymol
# naming
# charging
# multiple-instances
# install-from-source
# monit
# vmware-server
# torque
# gnome-extensions
# rotate-monitor
# gnuradio
# glsl
# shared-library
# webdav
# caching
# gradle
# dhcp
# selenium
# restricted
# sip
# indicator-datetime
# xbacklight
# input-language
# apache2
# audio
# visio
# yum
# apport-gtk
# googledart
# cube
# festival
# rpc
# nx
# segmentation-fault
# .profile
# mame
# windows-7
# globalmenu
# release-notes
# ebtables
# chrubuntu
# sox
# tethering
# grub-legacy
# ownership
# tightvncserver
# hp-pavilion
# proc
# ntp
# gettext
# screen-corruption
# recipe
# icecast
# installation
# hidpi
# lxrandr
# mkv
# winusb
# personalization
# tiling
# pbuilder-dist
# sed
# komodo-edit
# memory-test
# 8.10
# encoding
# openpgp
# cleanup
# fcitx
# pcsx
# hdpi
# usb-storage
# 3g
# crontab
# application-switcher
# virt-manager
# nepomuk
# scheduled
# amazon-ec2
# shortcuts
# mmc
# evolution-mapi
# virtual
# ubuntu-bug
# tablet
# hud
# adapter
# avidemux
# preinstallation
# markdown
# heroku
# mv
# automount
# video
# locale
# ubuntu-make
# interrupts
# vmware-tools
# gnome-documents
# hp-touchpad
# boxee
# curl
# flash-player
# ptp
# troubleshooting
# window
# cat
# gvfs
# i386
# ide
# turbo-boost
# derivatives
# wily
# filename
# openrc
# omemo
# intellij
# unity-2d
# remote-x-session
# btsync
# smarty
# keepassx
# kiosk
# teamspeak
# sshfs
# trojan
# kanji
# hive
# indicator-network
# zendframework
# nmap
# browser
# grunt
# authentication
# gnome-session-fallback
# ktorrent
# overlayfs
# exim
# jack
# accessibility
# neo4j
# file-type
# nfs
# expo-mode
# x11
# re-installation
# font-manager
# ustream
# ballview
# zotero
# microphone
# environment-variables
# youtube-dl
# diagnostic
# hfs+
# scidavis
# gif
# mime-type
# sound-menu
# ms-dos
# wireless-keyboards
# snap-windows
# firmware
# mobile
# dual-screen
# truecrypt
# users
# sandy-bridge
# elevation
# xev
# window-control
# indicator-applet-session
# liferea
# nux
# valgrind
# echo
# x-forwarding
# games
# obs-studio
# capture
# utox
# gtkrc
# xscreensaver
# libnotify
# v4l
# tlp
# defrag
# elementary
# format
# vmware-workstation
# kindle
# raid5
# window-manager
# claws
# ion
# usb-drive
# webkit
# splashtop
# lingot
# baloo
# kerberos
# ubuntu-website
# tui
# document
# adhoc
# ipsec
# webbrowser-app
# text-editor
# kmix
# groovy
# failover
# wubi
# shredding
# update-notifier
# dnsmasq
# wsl
# drm
# keyboard-layout
# fortran
# pdftk
# convert-command
# yoga-2
# edac
# broadband
# sd-card
# mtp
# dropbox
# more
# clock
# inputrc
# ppc
# brasero
# foxitreader
# thunderbird
# xdiagnose
# lens
# kompozer
# gtk-2
# idle-python
# asus-laptop
# triple-boot
# zentyal
# multiple-desktops
# uuid
# touch-command
# media
# passphrase
# xenial
# rotate
# 18.04
# right-to-left
# qa
# xnview
# proxy
# printer
# internationalization
# kickstart
# catalyst
# roundcube
# ark
# wii
# syslog
# upstart
# vlan
# dleyna
# telnet
# w64codecs
# dv6
# ncurses
# input-method
# runescape
# last.fm-client
# php
# release-upgrade
# gem
# precise
# vdi
# plasma-5
# optical
# vcd
# fakeroot
# saucy
# navigation
# slim
# pluma
# high-availability
# 15.04
# chromium
# daap
# plymouth
# read-only
# sqlite3
# notes
# msi
# rkhunter
# pdf
# unity
# glippy
# berkeleydb
# ubuntu-server
# emesene
# indicator-sound
# creative-zen
# mp4
# terminator
# video-player
# webp
# dead-keys
# selinux
# teminal-bell
# cursor-theme
# magento
# yed
# regex
# meep
# russian
# platform-integration
# image-processing
# ac3
# mir
# otrs
# 17.04
# arm64
# clutterflow
# ifs
# unity-previews
# io
# magic-trackpad
# ip-address
# uwsgi
# unsupported-packages
# dragon
# package-manager
# lspci
# rufus
# compaq
# projector
# mobile-broadband
# lighttpd
# audio-jack
# svn
# dvd-backup
# embedded-system
# nomachine
# sputnik
# settings
# guake
# mumble
# dynamic-ip
# banner
# ddclient
# video-conversion
# xorg.conf
# krunner
# unmount
# upnp
# ogg-vorbis
# window-buttons
# uptime
# r
# cloning
# ubuntu-one-music-store
# dev
# gnu
# alienware
# fontsize
# pandora
# wakeonlan
# wifi-hardware-switch
# kivy
# mariadb
# google-calendar
# telinit
# compression
# keybindings
# motherboard
# configuration-management
# visudo
# chrome
# ibm-lotus-notes
# symlink
# myunity
# traceroute
# install
# copy-and-paste
# voip
# iphoto
# indicator-power
# intel-nuc
# text-processing
# xfce4-power-manager
# marlin
# anaconda
# lynis
# redis
# audacious
# itunes
# file-roller
# smplayer
# django
# makerware
# gdisk
# accomplishments
# repository
# nano
# qgtkstyle
# hundredpapercuts
# unity-hud
# libav
# ircd-hybrid
# orca
# x2goclient
# device-name
# primus
# geary
# gcal
# upgrades
# dd
# mutiny
# touchegg
# ace
# alsa
# dockbarx
# rtorrent
# burner
# compilation-target
# fluxbox
# dosbox
# lxpanel
# apt-listchanges
# kill
# gpu-drivers
# eog
# vector-drawings
# cpu-load
# objdump
# neovim
# w3m
# external-monitor
# transcode
# natty
# dns
# cal
# ntfs
# video-streaming
# ubuntu-for-android
# lsof
# opengl
# ps3
# weather
# debdelta
# popup-ads
# rarcrack
# atheros
# german
# google-chat
# initrd
# lxml
# windows-subsystem-for-linux
# tweak
# easter-egg
# mono
# onscreen-keyboard
# viewports
# enigmail
# oss
# torrent-client
# nitroshare
# playonlinux
# hot-spot
# seq
# calligra
# vnstat
# share
# stable-release-updates
# disk-ripping
# wc
# git
# pg
# can
# mkusb
# oxygen
# blender
# anki
# cpuinfo
# system-tray
# ubuntu-17.10
# eject
# ubuntu-studio
# gnome-shell
# transparency
# cobbler
# gitlab
# byobu
# 13.10
# tpm
# encryption
# quantal
# lan
# sqldeveloper
# cd-drive
# nodejs
# shutdown
# application-submission
# installer
# synaptic
# rxvt
# wma
# crouton
# batch-rename
# org-mode
# xsel
# permanent-delete
# lanschool
# equalizer
# dnscrypt-proxy
# scons
# workspace-switcher
# gitosis
# firefox-5
# hotplug
# maximized
# project-management
# xmind
# restore
# minidlna
# resource-limiting
# elantech
# init.d
# openstack-autopilot
# openmediavault
# split
# ebooks
# mssql
# scp
# encrypted-partition
# places
# dbus
# zoneminder
# desktop-icons
# ubuntuone
# lxd
# oem
# rdiff-backup
# odoo
# data-loss
# slideshow
# yelp
# fish
# tv-tuner
# pycharm
# dmesg
# gnome-activity-journal
# switchers
# davfs2
# dotnet
# bandwith
# bluez
# policykit
# webcam
# gconf
# debootstrap
# wireless-n
# android-sdk
# password-recovery
# skype
# antialiasing
# backtrack
# maas
# utouch
# external-hdd
# button
# rvm
# desktop-directories
# ussd
# gmusicbrowser
# donation
# irssi
# editing
# makefile
# budgie
# rhythmbox
# usb-c
# .ttf
# ls
# quota
# job-control
# cpufreq
# abiword
# whatsapp
# nic
# shell
# banshee
# unionfs
# firewire
# gimp
# usb
# emulation
# virtualbox
# mycroft
# adsl
# zeroconf
# apt-cacher-ng
# compton
# ekiga
# input
# rtc
# white-screen
# rdesktop
# arm
# auto-completion
# etherape
# disk-utility
# network-bonding
# hp
# boot
# kupfer
# google-musicmanager
# aspire
# mpris
# notepadqq
# pastebin
# porting
# jdownloader
# magic-mouse
# aspire-one
# sh
# apt-cache
# hibernate
# x121e
# 32
# modules
# container
# minimal-install
# emmc
# simplescan
# vmware
# subtitle
# bootable-usb
# lirc
# arabic
# pandoc
# gnome3
# text-mode
# sqlite
# tee
# sawfish
# adapt
# dictionary
# update-history
# drivers
# kubuntu-desktop
# shortcut
# preseed
# yad
# hyper-v
# scilab
# xdmx
# spyder
# ping
# nexus-10
# sshd
# toshiba
# livestreamer
# launcher
# wkhtmltopdf
# doxygen
# broadcom
# manual
# customizer
# 12.04.4
# installation-problem
# passwd-file
# .bash-history
# hunspell
# acl
# remote
# lid
# openchrome
# ubuntu-on-arm
# gnome-tweak-tool
# asciidoc
# keyboard-shortcut
# beagleboard
# orientation
# add-ons
# ffmpeg
# squashfs
# mint
# 12.10
# stackapplet
# timidity
# tunnel
# ada
# motif
# ufw
# pointers
# transparent-proxy
# low-power
# gnu-r
# gedit
# sharing
# monodevelop
# soundconverter
# grub2
# gtalk
# stat
# audio-player
# testdrive
# iceweasel
# microk8s
# ethernet
# audio-sync
# sysv
# google-drive
# microsoft-keyboard
# bios
# openvpn
# mediatomb
# wxpython
# 3d
# lubuntu
# vaapi
# gobject
# mesh
# removing
# calendar
# home-automation
# dput
# pidgin-sipe
# connection-sharing
# background
# launchpad
# ubuntu-membership
# lvm
# google-earth
# icc
# burg
# equivs
# motd
# google-talk
# scopes
# broken-packages
# citrix
# expresscard
# self-signed
# ubuntu-one
# dhcpd
# tesseract
# codecs
# tmp
# blackberry
# jshint
# tar
# file-properties
# process
# duplicity
# dell-mini-9
# cgroup
# lpd
# maildir
# dkim
# alfa-wireless
# address-book
# h264
# cacti
# do-release-upgrade
# easycap
# engine
# gnome-do
# ipod
# tty
# cloud-init
# execute-command
# downloads
# hardware-acceleration
# templates
# gsync
# winff
# cddb
# system-language
# reinstalling
# efi
# x64
# core-apps
# battery
# orange-box
# 14.04.2
# classic
# privoxy
# clipboard
# ubuntu-tweak
# bricscad
# evolution
# conjure-up
# lucid
# iperf
# decryption
# palemoon
# unzip
# gnumeric
# modem-manager
# non-pae
# sftp
# texas-instruments
# apache-tomcat
# inode
# dual-monitor
# eclipse
# gnomevfs
# daw
# surface
# cpu
# bkchem
# systemd-resolved
# modem
# titlebar
# dmraid
# qemu
# official-repositories
# cr-48
# expect
# android
# google-video
# wps-office
# xfdesktop
# hvr-2250
# spread
# computestick
# docky
# microsoft
# netbook
# untagged
# cinelerra
# 12.04.2
# ntfs-3g
# varnish
# autohide
# qcow2
# qdbus
# exif
# pyqt5
# hexchat
# vector
# toxic
# live-environment
# postgres
# minimal
# fail2ban
# pesistence
# shm
# power-cog
# disk-image
# usbhid
# alias
# rekonq
# ddrescue
# photo-management
# portable
# ubuntu-store
# phppgadmin
# usb-creator
# novell-netware
# badblocks
# bluetooth
# startup-disk
# modelines
# command-line
# teaching
# tt-rss
# url
# mpi
# network
# vmware-fusion
# odt
# rdio
# id3
# virtualmin
# migration
# sddm
# dvd
# custom-distributions
# atom
# jupiter
# dkms
# powernap
# huawei
# virtualdesktop
# mp3
# uec
# gstreamer
# download-speed
# extract
# synfig-studio
# logout
# usbview
# cowsay
# backlight
# ac100
# click-policy
# gtk
# nmcli
# open-drive
# usb-device
# ip
# kamoso
# debian-installer
# microcode
# data-corruption
# qt-creator
# hardware-reccomendation
# radvd
# keyrings
# jython
# asterix
# audiobooks
# keys
# startup-applications
# remote-login
# mesa
# x
# last-command
# appstream
# grubrescue
# cuda
# social
# aptoncd
# spamassassin
# tuxpaint
# update
# adobe-brackets
# ejabberd
# vaio
# sasl
# pommed
# deivatives
# chgrp
# qtox
# grub-error
# kde-apps
# unetbootin
# unity-3d
# canonical
# kontact
# playback
# gparted
# cron
# menu
# ibus
# mouse-wheel
# numpy
# windows
# xrdp
# gcalctool
# adb
# moinmoin
# unlock
# debug
# unistd
# applet
# pantheon
# sublime-text
# dracut
# clang
# evince
# karmic
# indicator-weather
# lxsession
# trademark
# powershell
# helpfile
# speakers
# twinview
# bzrlib
# mainline-kernel
# intel-smart-response
# pandas
# chinese
# autoplay
# iodbc
# puppet
# directory-structure
# router
# css
# evdev
# scrot-command
# ssh-keys
# dist-upgrade
# refind
# clamtk
# snort
# vulnerability
# processes
# rar
# make
# qsystemtrayicon
# emulator
# pam-environment
# dmcrypt
# bootcamp
# jockey
# mailman
# software-recommendations
# multi-touch
# xwinwrap
# malayalam
# launchpadlib
# appearance
# init
# ipython
# unity3d
# broadcasting
# lsusb
# partitions
# pitivi
# administrator
# mod-rewrite
# nas
# notification-area
# compiling
# hda-intel
# looking-glass
# scripts
# memenu
# display-resolution
# kodak
# tomcat8
# rtl
# held-packages
# indicator-multiload
# kernel-panic
# pgadmin
# gnome-control-center
# gnome-power-manager
# kindle-fire
# purge
# skel
# audacity
# touchpad
# wifi
# realtek
# application-finder
# hardware-certification
# virtual-file-system
# open-source
# gnome-terminal
# 64
# google-desktop
# file-sorting
# gtkinspector
# readline
# multi-user
# cmake
# miro
# rstudio
# kde-telepathy
# 9.10
# lamp
# nova
# internet
# active-directory
# compatibility
# gnome-screensaver
# pharo
# ram-usage
# shell-scripting
# update-alternatives
# apic
# digital-dairy
# opera
# pdfsam
# totem
# ubuntu-builder
# yakuake
# source-code
# keyboard
# unicode-entry
# canon
# efibootmgr
# heimdall
# smart-tv
# programming
# gma3600
# timestamp
# ensemble
# capslock
# cut-command
# libertine
# amavisd-new
# munin
# disk-usage
# perl
# plasma-netbook
# ifolder
# konqueror
# cpu-architecture
# watchdog
# kde4
# strace
# flash-drive
# powerline-plugin
# erlang
# amdgpu
# tftp
# root-permission
# get-iplayer
# archive
# bc
# twitter
# goldendict
# xdebug
# checkbox
# fonts
# graphics
# hybrid-graphics
# jvm
# likewise
# system-requirements
# instant-messaging
# libpng
# mysql
# mediawiki
# udev
# workflow
# swf
# chm
# cpupower
# file
# xpra
# jfs
# unprivileged
# input-devices
# automation
# dpkg
# droidcam
# putty
# qt4
# executable
# murmur
# nautilus-3.6
# virtual-terminal
# smartcard
# two-factor-authentication
# trackpoint
# flashplugin-installer
# hard-drive
# tail
# debian
# pelican
# hybrid-efi
# viber
# webgl
# xdg-open
# packet-analyzer
# laptop
# python3
# iotop
# friends-app
# nautilus-script
# c
# swap
# user-data
# foobar2000
# ipv4

# %%
df=pd.read_csv('questionsV7.csv',encoding = "ISO-8859-1")

# %%
df=df.iloc[0:len(df),1:8]
df.columns
# Out:
# Index(['Question Name', ' No.of Views', ' No.of answers', ' No.of Votes',
#        ' Question id', ' Tags', ' Date '],
#       dtype='object')

# %%
df.iloc[0:20,:]
# Out:
#                                         Question Name   No.of Views  \
# 0   My computer boots to a black screen what optio...     1300000.0
# 1   How do I install Ubuntu alongside a pre-instal...     1700000.0
# 2                            How do I install Ubuntu?      168000.0
# 3                Installing Broadcom Wireless Drivers     1400000.0
# 4       How to remove Ubuntu and put Windows back on?     1400000.0
# 5   How do I resolve unmet dependencies after addi...      873000.0
# 6   How can I repair grub? (How to get Ubuntu back...      647000.0
# 7   How to install software or upgrade from an old...      473000.0
# 8                              How do I report a bug?       57000.0
# 9   How do I find out which version and derivative...       87000.0
# 10     Unity doesn't load no Launcher no Dash appears      551000.0
# 11     How do I reset a lost administrative password?     2200000.0
# 12  How can I fix a 404 Error when using a PPA or ...      501000.0
# 13                          How to resize partitions?      320000.0
# 14                  Ubuntu gets stuck in a login loop      851000.0
# 15  My wireless/WiFi connection does not work. Wha...      244000.0
# 16  How to use manual partitioning during installa...     1100000.0
# 17              What should I do when Ubuntu freezes?      575000.0
# 18  Unable to mount Windows (NTFS) filesystem due ...      832000.0
# 19  How do I recover my accidentally lost Windows ...      134000.0
#
#     No.of answers   No.of Votes   Question id  \
# 0              32           451        162075
# 1              12           544        221835
# 2               2           158          6328
# 3              42           317         55868
# 4              16           185        133533
# 5              14           521        140246
# 6              11           331         88384
# 7               9           375         91815
# 8               7           450          5121
# 9               8           134        206407
# 10             34           545         17381
# 11             15           625         24006
# 12              8           252         65911
# 13              4           108        126153
# 14             45           442        223501
# 15              3            95        425155
# 16              6           217        343268
# 17             45           591          4408
# 18             21           316        145902
# 19              3            53        286181
#
#                                                  Tags       Date
# 0                                                boot   7/10/2012
# 1    dual-boot system-installation uefi windows-8 ...  12/11/2012
# 2                                 system-installation  10/12/2010
# 3    networking drivers wireless software-installa...    9/7/2011
# 4                                        windows disk   5/28/2012
# 5    apt software-installation package-management ...   5/21/2012
# 6                 dual-boot grub2 windows boot-repair  12/17/2011
# 7                                  release-management  12/31/2011
# 8                                       bug-reporting   10/3/2010
# 9    hardware versions compatibility system-requir...  10/25/2012
# 10                                              unity  12/14/2010
# 11                                  password-recovery   1/30/2011
# 12                                 apt ppa repository  10/14/2011
# 13                                       partitioning   4/27/2012
# 14                         login lightdm login-screen  11/29/2012
# 15                                           wireless   2/23/2014
# 16                   partitioning system-installation    9/9/2013
# 17                                      bug-reporting   9/20/2010
# 18                       windows mount ntfs hibernate    6/3/2012
# 19                      ntfs data-recovery partitions   4/26/2013

# %%
#SYNONYM EXTRACTOR
tagSynonymDict={}
for pageNo in range(1,5):  #No. of pages
    synonymUrl='https://askubuntu.com/tags/synonyms?page='+str(pageNo)+'&tab=newest&dir=descending&filter=active'
    uClient=uReq(synonymUrl)
    page_html=uClient.read()
    uClient.close()
    page_soup=soup(page_html,"html.parser")
    tag_synonym=page_soup.findAll("a",{"class":"post-tag"})
    #No of tags are 32
    #no of pairs are 32/2 ie 16 
    for i in range (int(len(tag_synonym)/2)):  #32 iterations
        tagSynonymDict[re.findall(r'>.*</a>',str([tag_synonym[i*2]]))[0].replace('>',"").replace('</a',"")]=re.findall(r'>.*</a>',str([tag_synonym[(i*2)+1]]))[0].replace('>',"").replace('</a',"")

# %%
(tagSynonymDict)
# Out:
# {'.bash-history': 'bash',
#  '.deb': 'deb',
#  '.sh': 'scripts',
#  '12.04.1': '12.04',
#  '12.04.2': '12.04',
#  '12.04.3': '12.04',
#  '12.04.4': '12.04',
#  '12.04.5': '12.04',
#  '12.04lts': '12.04',
#  '14.04.2': '14.04',
#  '14.04.4': '14.04',
#  '14.04.x': '14.04',
#  '18.04.01': '18.04',
#  '18.04.1': '18.04',
#  '32': '32-bit',
#  '64': '64-bit',
#  'a11y': 'accessibility',
#  'acpid': 'acpi',
#  'add-ons': 'plugins',
#  'addon': 'plugins',
#  'amd64': '64-bit',
#  'apache': 'apache2',
#  'apache-tomcat': 'tomcat',
#  'app-install': 'installation',
#  'appindicator': 'indicator',
#  'application-review-board': 'application-submission',
#  'applications-menu': 'appmenu',
#  'apport-gtk': 'apport',
#  'apt-get': 'apt',
#  'asterix': 'asterisk',
#  'asus-laptop': 'asus',
#  'asus-pc': 'asus',
#  'ati': 'amd-graphics',
#  'audio': 'sound',
#  'bandwith': 'bandwidth',
#  'bionic': '18.04',
#  'boot-failure': 'boot',
#  'boot-screen': 'plymouth',
#  'bootable-usb': 'live-usb',
#  'booting': 'boot',
#  'bootup': 'boot',
#  'broken-packages': 'package-management',
#  'build': 'compiling',
#  'bzr': 'bazaar',
#  'charms': 'juju',
#  'chrome': 'google-chrome',
#  'classic': 'gnome',
#  'cli': 'command-line',
#  'cmd': 'command-line',
#  'command': 'command-line',
#  'command-line-tools': 'command-line',
#  'commands': 'command-line',
#  'compile': 'compiling',
#  'connections': 'connection',
#  'console': 'command-line',
#  'crashes': 'crash',
#  'cron-jobs': 'cron',
#  'crontab': 'cron',
#  'cups': 'printing',
#  'daemon': 'services',
#  'dash': 'unity-dash',
#  'decompression': 'compression',
#  'deivatives': 'derivatives',
#  'dependency': 'dependencies',
#  'dev': 'development',
#  'directories': 'directory',
#  'dist-upgrade': 'upgrade',
#  'download': 'downloads',
#  'driver': 'drivers',
#  'dual-monitor': 'multiple-monitors',
#  'dual-screen': 'multiple-monitors',
#  'dualhead': 'multiple-monitors',
#  'efi': 'uefi',
#  'encrypted-partition': 'encryption',
#  'ensemble': 'juju',
#  'file': 'files',
#  'file-extension': 'file-format',
#  'file-size': 'files',
#  'find-command': 'find',
#  'firefox-4': 'firefox',
#  'firefox-5': 'firefox',
#  'firefox-nightly': 'firefox',
#  'flash-drive': 'usb-drive',
#  'flash-player': 'flash',
#  'flash-plugin': 'flash',
#  'flashplugin-installer': 'flash',
#  'flashplugin-nonfree': 'flash',
#  'folder': 'directory',
#  'folders': 'directory',
#  'font': 'fonts',
#  'font-rendering': 'fonts',
#  'fontconfig': 'fonts',
#  'fontsize': 'fonts',
#  'game': 'games',
#  'gaming': 'games',
#  'gnome-fallback': 'gnome-classic',
#  'gnome3': 'gnome',
#  'go': 'golang',
#  'gpg': 'gnupg',
#  'grub': 'grub2',
#  'grub-error': 'grub2',
#  'hardware-reccomendation': 'hardware-recommendation',
#  'hardy': '8.04',
#  'hdd': 'hard-drive',
#  'hidpi': 'hdpi',
#  'home': 'home-directory',
#  'home-server': 'server',
#  'hundredpapercuts': 'one-hundred-paper-cuts',
#  'i18n': 'internationalization',
#  'i386': '32-bit',
#  'icon': 'icons',
#  'impress': 'libreoffice',
#  'indicator-applet-session': 'indicator',
#  'indicator-datetime': 'indicator',
#  'indicator-network': 'indicator',
#  'indicator-power': 'indicator',
#  'indicator-session': 'indicator',
#  'indicator-weather': 'indicator',
#  'install': 'installation',
#  'install-from-source': 'software-installation',
#  'installation-failure': 'installation',
#  'installation-problem': 'installation',
#  'installer': 'installation',
#  'installing': 'installation',
#  'intallation': 'installation',
#  'intel-wireless': 'iwlwifi',
#  'internet-connection': 'internet',
#  'ion': 'nvidia',
#  'karmic': '9.10',
#  'kernel-modules': 'kernel',
#  'kernel-option': 'kernel',
#  'kernel-panic': 'kernel',
#  'key-bindings': 'shortcut-keys',
#  'key-combination': 'shortcut-keys',
#  'keybindings': 'shortcut-keys',
#  'keyboard-shortcut': 'shortcut-keys',
#  'keyboard-shortcuts': 'shortcut-keys',
#  'kindle-fire': 'kindle',
#  'kubuntu-desktop': 'kubuntu',
#  'lampp': 'lamp',
#  'lens': 'lenses',
#  'lense': 'lenses',
#  'libreoffice-calc': 'libreoffice',
#  'libreoffice-impress': 'libreoffice',
#  'libreoffice-writer': 'libreoffice',
#  'libvirt': 'virtualization',
#  'livecd': 'live-cd',
#  'locales': 'locale',
#  'lucid': '10.04',
#  'mainline-kernel': 'kernel',
#  'man': 'manpage',
#  'manual': 'documentation',
#  'maverick': '10.10',
#  'memory': 'ram',
#  'minimal': 'ubuntu-minimal',
#  'mobile': 'ubuntu-touch',
#  'modules': 'drivers',
#  'multiboot': 'dual-boot',
#  'mv-command': 'mv',
#  'nagios': 'nagios3',
#  'natty': '11.04',
#  'nautilus-3.6': 'nautilus',
#  'netbook': 'ubuntu-netbook',
#  'netbook-edition': 'ubuntu-netbook',
#  'network': 'networking',
#  'nm-applet': 'network-manager',
#  'nvidia-current': 'nvidia',
#  'oneiric': '11.10',
#  'oneric': '11.10',
#  'osx': 'macosx',
#  'package': 'package-management',
#  'package-manager': 'package-management',
#  'packages': 'package-management',
#  'partition': 'partitioning',
#  'passwords': 'password',
#  'pendrive': 'usb-drive',
#  'pesistence': 'persistent',
#  'php-5.4': 'php',
#  'php5': 'php',
#  'plexmediaserver': 'plex',
#  'plugin': 'plugins',
#  'polkit': 'policykit',
#  'postgres': 'postgresql',
#  'postgresql-8.4': 'postgresql',
#  'power': 'power-management',
#  'poweroff': 'shutdown',
#  'ppc': 'powerpc',
#  'precise': '12.04',
#  'precise-pangolin': '12.04',
#  'printer': 'printing',
#  'printer-driver': 'printing',
#  'privileges': 'permissions',
#  'processes': 'process',
#  'processor': 'cpu',
#  'proposed-updates': 'updates',
#  'qa': 'quality',
#  'quality-assurance': 'quality',
#  'quantal': '12.10',
#  'radio': 'internet-radio',
#  'raring': '13.04',
#  're-installation': 'installation',
#  'recommendations': 'tips',
#  'recovery': 'data-recovery',
#  'release': 'release-management',
#  'release-upgrade': 'upgrade',
#  'remote-control': 'remote',
#  'removal': 'uninstall',
#  'remove': 'uninstall',
#  'repositories': 'repository',
#  'resolution': 'display-resolution',
#  'right-to-left': 'rtl',
#  'rights': 'permissions',
#  'root-permission': 'permissions',
#  'rotate-monitor': 'display-rotation',
#  'saucy': '13.10',
#  'scanning': 'scanner',
#  'scheduled': 'schedule',
#  'script': 'scripts',
#  'scripting': 'scripts',
#  'secure-delete': 'secure-erase',
#  'setup': 'installation',
#  'share': 'sharing',
#  'shell': 'command-line',
#  'shell-scripting': 'scripts',
#  'shortcut': 'shortcuts',
#  'shortcuts-keys': 'shortcut-keys',
#  'silverlight': 'moonlight',
#  'sleep': 'suspend',
#  'snap-package': 'snap',
#  'snapcraft': 'snap',
#  'snappy': 'ubuntu-core',
#  'soft-link': 'symbolic-link',
#  'software-recommendations': 'software-recommendation',
#  'software-updater': 'update-manager',
#  'sound-menu': 'indicator-sound',
#  'sound-problem': 'sound',
#  'sources.list': 'software-sources',
#  'space': 'disk-usage',
#  'splash': 'plymouth',
#  'splash-screen': 'plymouth',
#  'spread': 'promotion',
#  'squid3': 'squid',
#  'ssh-keys': 'ssh',
#  'stable-release-updates': 'updates',
#  'sudoers': 'sudo',
#  'suspend-resume': 'suspend',
#  'switchers': 'workspace-switcher',
#  'symlink': 'symbolic-link',
#  'synchronize': 'sync',
#  'system-wide': 'system',
#  'systray': 'system-tray',
#  'teaching': 'education',
#  'terminal': 'command-line',
#  'theme': 'themes',
#  'titlebar-buttons': 'window-buttons',
#  'torrent': 'bittorrent',
#  'touch': 'ubuntu-touch',
#  'trackpad': 'touchpad',
#  'triple-boot': 'dual-boot',
#  'trusty': '14.04',
#  'ubuntu': 'ubuntu-desktop',
#  'ubuntu-12.04': '12.04',
#  'ubuntu-15.10': '15.10',
#  'ubuntu-17.10': '17.10',
#  'ubuntu-bug': 'bug-reporting',
#  'ubuntu-for-phones': 'ubuntu-touch',
#  'ubuntu-netbook-remix': 'ubuntu-netbook',
#  'ubuntu-on-arm': 'arm',
#  'ubuntu-one-music-store': 'ubuntu-one',
#  'ubuntu-phone': 'ubuntu-touch',
#  'ubuntu-server': 'server',
#  'ubuntu-software-center': 'software-center',
#  'ubuntu13.04': '13.04',
#  'ubuntu14.04': '14.04',
#  'ubuntuone': 'ubuntu-one',
#  'unicorn': '14.10',
#  'unity-3d': 'unity',
#  'unity-hud': 'hud',
#  'unity-launcher': 'launcher',
#  'unity-launcher-api': 'unity',
#  'unr': 'ubuntu-netbook',
#  'update': 'updates',
#  'upgrades': 'upgrade',
#  'upgrading': 'upgrade',
#  'user-accounts': 'users',
#  'utc-time': 'time',
#  'utopic': '14.10',
#  'utouch': 'multi-touch',
#  'vbox': 'virtualbox',
#  'version': 'versions',
#  'version-upgrade': 'upgrade',
#  'virtual-machine': 'virtualization',
#  'virtual-terminal': 'virtual-console',
#  'viruses': 'malware',
#  'vista': 'windows-vista',
#  'vlc-player': 'vlc',
#  'vm': 'virtualization',
#  'vmplayer': 'vmware',
#  'vsftp': 'vsftpd',
#  'vt-x': 'virtualization',
#  'wifi': 'wireless',
#  'wily': '15.10',
#  'window-control': 'window-buttons',
#  'windows-active-directory': 'active-directory',
#  'winxp': 'windows-xp',
#  'wireless-n': 'wireless',
#  'wlan': 'wireless',
#  'writer': 'libreoffice',
#  'wsl': 'windows-subsystem-for-linux',
#  'x': 'xorg',
#  'x11': 'xorg',
#  'x64': '64-bit',
#  'xenial': '16.04',
#  'xfce4': 'xfce',
#  'xp': 'windows-xp',
#  'xubuntu-desktop': 'xubuntu'}

# %%
#This is temporary not to be used in real code
#tag count per answer
answerTagDict={}
for question in range(0,5):
        my_url='https://askubuntu.com/questions/'+str(df.iloc[question,4])
        uClient=uReq(my_url)
        page_html=uClient.read()
        uClient.close()
        page_soup=soup(page_html,"html.parser")
        answer_summary=page_soup.findAll("div",{"class":"post-text"})
        complete_answer=""
        
        complete_answer=complete_answer+" "+str(answer_summary[1]) #consider only the 1st answer since it has max upvotes
        temp=re.sub(r'<a href.*</a>'," ",str(complete_answer))
        temp=re.sub(r'<code>.*</code>'," ",str(temp))
        temp=re.sub(r'<.{1,50}>'," ",str(temp))
        temp=re.sub(r'\. '," ",str(temp))
        temp=temp.replace("(","").replace(")","").replace(",","").replace("/"," ").replace("\\"," ").replace("!"," ").replace(":","")
        temp=' '.join(temp.split())
        
        tempList=[word for word in str(temp).lower().split() if not word in stopwords.words('english')]
       
        tempVar=([i in tagSynonymDict for i in tempList]) #list of boolean values 
        
        for i in range(len(tempVar)):
            if tempVar[i]:
                tempList[i]=tagSynonymDict[tempList[i]]
                #answerTagDict1[df.iloc[question,4]]=Counter(tempList)
                answerTagDict[df.iloc[question,4]]= dict((k,v) for k,v in Counter(tempList).items() if k in set(tagSet))

# %%
sum(answerTagDict[162075].values())
# Out:
# 154

# %%
#TESTING PURPOSE
fruits = ['apples', 'bananas', 'pears']
fruit_dict1 = {'apples': 4, 'oranges': 3, 'dragonfruit': 4,'pinnaple':20}
tempVar=([i in fruit_dict1 for i in fruits])
print(x)  
for i in range(len(tempVar)):
    if tempVar[i]:
        fruits[i]=fruit_dict1[fruits[i]]
print(fruits)
# Out:
# [True, False, False]
# [4, 'bananas', 'pears']

# %%
print(fruits)
# Out:
# [4, 'bananas', 'pears']

# %%
len(tagSet)
# Out:
# 3276

# %%
df1=pd.DataFrame(columns=['Question Name','No.of Views','No.of answers','No.of Votes',
                          'Question id','Tags By User','Date','Urls','Tags In Question','Tags In Answer','Votes on Answer','Tag Count'])

# %%
len(df1)
# Out:
# 0

# %%
count=0
tempStorage=0

start_time=calendar.timegm(time.gmtime())
answerTagDict={}

for question in range(0,10):
    try:
        my_url='https://askubuntu.com/questions/'+str(df.iloc[question,4])
        uClient=uReq(my_url)
        page_html=uClient.read()
        uClient.close()
        page_soup=soup(page_html,"html.parser")
        answer_summary=page_soup.findAll("div",{"class":"post-text"})
        complete_answer=""
        
        complete_answer=complete_answer+" "+str(answer_summary[1])
        temp=re.sub(r'<a href.*</a>'," ",str(complete_answer))
        temp=re.sub(r'<code>.*</code>'," ",str(temp))
        temp=re.sub(r'<.{1,50}>'," ",str(temp))
        temp=re.sub(r'\. '," ",str(temp))
        temp=temp.replace("(","").replace(")","").replace(",","").replace("/"," ").replace("\\"," ").replace("!"," ").replace(":","")
        temp=' '.join(temp.split())
        temp=temp.lower()
        
        tempSet=set(temp.split())
        #print(tempSet)
        
        #Upvotes
        upvoteValue=page_soup.find_all("div",{"itemprop":"upvoteCount"})

        upvoteValue=str(re.findall(r'>.*</div>',str(upvoteValue[1]))[0]).replace(">","").replace("</div","")
        
        questionKeywords=[word for word in str(df.iloc[question,0]).lower().split() if not word in stopwords.words('english')]
        
        #remove the stop words from the answer
        #tempList=[word for word in str(temp).lower().split() if not word in stopwords.words('english')]
        tempList=[word for word in str(temp).lower().split() if word in list(tagSet)]
        
        if question==8:
            print(tempList)
            print('------------------------------------------------------------------')
       
        tempVar=([i in tagSynonymDict for i in tempList]) #list of boolean values to check if the word in tempList has synonym
        
        for i in range(len(tempVar)):
            if tempVar[i] and (tagSynonymDict[tempList[i]] in tagSet):
                tempList[i]=tagSynonymDict[tempList[i]] #replace synonym words in the list with a same word

                
        answerTagDict[df.iloc[question,4]]= dict((k,v) for k,v in Counter(tempList).items() if k in set(tagSet))
        
        if question==8:
            print(tempList)
            print("answer tags are: "+str(tagSet.intersection(tempSet)))

        
        #question name, no.of views,no.of answers,no. of votes,question id,tags by user,date,urls,tags in question,tags in answer,votes on answer
        df1.loc[question]=str(df.iloc[question,0]),str(df.iloc[question,1]),str(df.iloc[question,2]),str(df.iloc[question,3]),str(df.iloc[question,4]),str(df.iloc[question,5]),str(df.iloc[question,6]),str(my_url),str(tagSet.intersection(set(questionKeywords))), str(tagSet.intersection(tempSet)),str(upvoteValue),str(answerTagDict[df.iloc[question,4]])
        
        print("Question No: "+str(count))
        count=count+1
        tempStorage=tempStorage+1
        if tempStorage==500:
            df1.iloc[(count-500):count].to_csv('TagDataNew'+str(count)+'.csv')  #Create csv file for every 500 questions
            tempStorage = 0
         
    except Exception as e:
        print("Error is "+str(e))
        break
        end_time=calendar.timegm(time.gmtime())
        total_time=(end_time-start_time)/3600
        print("Total time taken before  "+str(count)+" questions in hours: "+str(total_time))
        print(e)
        print("Delay of 180 secs")
        time.sleep(180)

end_time=calendar.timegm(time.gmtime())
total_time=(end_time-start_time)/3600
print("Total time taken after all questions "+str(count)+" questions in hours: "+str(total_time))
df1.to_csv('CompleteTagData.csv')
print("Successfully Saved ALL QUESTIONS"+str(count))
# Out:
# Question No: 0
# Question No: 1
# Question No: 2
# Question No: 3
# Question No: 4
# Question No: 5
# Question No: 6
# Question No: 7
# ['ubuntu', 'window', 'more']
# ------------------------------------------------------------------
# ['ubuntu', 'window', 'more']
# answer tags are: {'ubuntu', 'window', 'more'}
# Question No: 8
# Question No: 9
# Total time taken after all questions 10 questions in hours: 0.005833333333333334
# Successfully Saved ALL QUESTIONS10

# %%
#Create data structure coloums for tf idf values for each tag for answer to each question
len(tagSet)
# Out:
# 3338

# %%
set(tagSynonymDict.keys())
# Out:
# 316

# %%
len(tagSet-set(tagSynonymDict.keys()))
# Out:
# 3022

# %%
len(set(tagSynonymDict.values()))
# Out:
# 190

# %%
(tagSet | set(tagSynonymDict.values()))-set(tagSet) #critical for assesment
# Out:
# {'hardware-recommendation', 'tips', 'ubuntu-desktop'}

# %%
#THE  CRITICAL LINE 
question='question'
#tagColoumn=list( ( tagSet-set(tagSynonymDict.keys()) ) | ( (tagSet | set(tagSynonymDict.values()))-set(tagSet) ) )
tagColoumn=list(  (tagSet | set(tagSynonymDict.values())))   #critical line containg all tags
tagColoumn.insert(0,question)
tfIdfDataFrame=pd.DataFrame(columns=tagColoumn)
print(tfIdfDataFrame)
# Out:
# Empty DataFrame
# Columns: [question, chrome, framebuffer, subnet, mp3-player, atom, grub-legacy, lanschool, sms, intel-atom, dhcpd, bandwith, pim, backup, flareget, samsung, tcpdump, diagram, ubuntu-netbook, citrix, emoji, mssql, hostname, moinmoin, javascript, rodbc, lamp, scripting, sqlite, vnc, who, gnucash, uds, bitcoin, mathematica, 14.04, audacious, oracle, cisco, graphics, daap, adobe, restart, disk-usage, xbindkeys, nautilus, dkim, neo4j, chroot, pianobar, selenium, tips, 14.04.2, artwork, kindle-fire, dia, installing, apturl, kubuntu, boinc, xonsh, gnome-fallback, indicator-syc, input-language, mod-rewrite, 7zip, favorites, zimbra, login, plasma-5, youtube, locoteams, dovecot, idevices, bash, nat64, grep, scp, openssh, xinerama, gif, internet-connection, audio-player, mail-notification, lintian, searchmonkey, lampp, aif, stackapplet, voice-recognition, zsnes, gpt, maintenance, burner, dlna, apache2.4, rails, nano, geolocation, vlc-player, ...]
# Index: []
#
# [0 rows x 3342 columns]

# %%
len(tagColoumn)
# Out:
# 3342

# %%
totalRows=len(completeTagData)
tagIdf=dict.fromkeys(list( (tagSet | set(tagSynonymDict.values()))) ,0)   #all tags entered to tagIdf dictionary

for i in range (len(completeTagData)):
    for j in (list(   set(ast.literal_eval(completeTagData[i]).keys()).intersection(tagIdf.keys()) ) ):
        tagIdf[j]=tagIdf[j]+1

        
for i in tagIdf.keys():
    if tagIdf[i]!=0:
        tagIdf[i]=math.log10(totalRows/tagIdf[i])

# %%
len(tagTfIdf)
# Out:
# 3341

# %%
#calculate idf for each tag
#This is correct
completeTagData=df=pd.read_csv('CompleteTagData.csv',encoding = "ISO-8859-1")
completeTagData=completeTagData.iloc[:,[1,12]]
completeTagData.head()
# Out:
#                                        Question Name  \
# 0  My computer boots to a black screen what optio...
# 1  How do I install Ubuntu alongside a pre-instal...
# 2                           How do I install Ubuntu?
# 3               Installing Broadcom Wireless Drivers
# 4      How to remove Ubuntu and put Windows back on?
#
#                                            Tag Count
# 0  {'cd': 2, 'dvd': 2, 'usb': 2, 'flash': 1, 'dri...
# 1  {'ubuntu': 82, 'compatibility': 2, 'versions':...
# 2  {'downloads': 2, 'versions': 3, 'ubuntu': 11, ...
# 3  {'ubuntu': 10, 'users': 3, 'broadcom': 13, 'wh...
# 4  {'system': 2, 'ubuntu': 10, 'can': 5, 'install...

# %%
tagTfIdf={}
tempData={}
for i in range (len(completeTagData)):
    for key,value in ast.literal_eval(completeTagData.iloc[i,1]).items():
        tempData[key]=(value)*(tagIdf[key])
    tagTfIdf[completeTagData.iloc[i,0]]= tempData
    tempData={}

# %%
tagTfIdf
# Out:
# {'How can I fix a 404 Error when using a PPA or updating my package lists?': {'11.10': 2.0,
#   '15.04': 1.0,
#   'apt': 0.3010299956639812,
#   'button': 0.9118639112994488,
#   'client': 1.3010299956639813,
#   'command-line': 0.18708664335714445,
#   'deb': 1.0,
#   'etc': 0.6020599913279624,
#   'file-format': 1.3010299956639813,
#   'files': 0.2596373105057561,
#   'find': 0.3979400086720376,
#   'gedit': 1.3010299956639813,
#   'gksu': 1.3010299956639813,
#   'hosting': 1.0,
#   'jupiter': 2.6020599913279625,
#   'package-management': 0.6020599913279624,
#   'ppa': 5.0,
#   'repository': 1.0457574905606752,
#   'server': 2.0969100130080567,
#   'software-sources': 1.6478174818886375,
#   'source': 0.6989700043360189,
#   'text': 1.0,
#   'ubuntu': 0.49975494643319973,
#   'uninstall': 0.3979400086720376,
#   'update-manager': 1.3010299956639813,
#   'updates': 0.6020599913279624,
#   'url': 1.3010299956639813,
#   'users': 0.4559319556497244,
#   'versions': 0.3467874862246563},
#  'How can I repair grub? (How to get Ubuntu back after installing Windows?)': {'boot': 1.7747899969308512,
#   'cd': 0.3467874862246563,
#   'chroot': 1.3010299956639813,
#   'command-line': 0.18708664335714445,
#   'configuration': 0.5228787452803376,
#   'development': 7.8061799739838875,
#   'etc': 0.6020599913279624,
#   'find': 0.3979400086720376,
#   'fstab': 1.0,
#   'golang': 0.4559319556497244,
#   'grep': 2.0,
#   'grub2': 4.892790030352132,
#   'installation': 0.8873949984654256,
#   'lvm': 1.0,
#   'make': 0.3467874862246563,
#   'mode': 1.3677958669491732,
#   'mount': 3.612359947967774,
#   'partitioning': 4.10338760084752,
#   'partitions': 0.4559319556497244,
#   'proc': 1.3010299956639813,
#   'reboot': 0.3979400086720376,
#   'redirect': 1.3010299956639813,
#   'reinstall': 1.6478174818886375,
#   'root': 0.5228787452803376,
#   'session': 0.8239087409443188,
#   'sudo': 2.7742998897972506,
#   'system': 0.5612599300714334,
#   'ubuntu': 0.24987747321659987,
#   'uefi': 4.214419939295737,
#   'updates': 0.6020599913279624,
#   'usb': 0.2596373105057561,
#   'users': 0.4559319556497244,
#   'uuid': 3.9030899869919438,
#   'windows': 1.8237278225988975},
#  'How do I find out which version and derivative of Ubuntu is right for my hardware in terms of minimal system requirements?': {'14.04': 2.0969100130080567,
#   '16.04': 4.943452445665913,
#   '17.10': 2.6020599913279625,
#   '18.04': 10.0,
#   '18.10': 1.3010299956639813,
#   '19.04': 1.3010299956639813,
#   '32-bit': 2.4717262228329564,
#   '64-bit': 6.29073003902417,
#   'adapter': 1.6478174818886375,
#   'architecture': 1.0,
#   'arm': 2.6020599913279625,
#   'boot': 0.4436974992327128,
#   'can': 0.18708664335714445,
#   'cd': 1.3871499448986253,
#   'cloud': 1.3010299956639813,
#   'community': 1.0,
#   'compiling': 1.0,
#   'cpu': 14.0,
#   'date': 1.0,
#   'derivatives': 2.6020599913279625,
#   'devices': 1.6478174818886375,
#   'disk': 3.1372724716820257,
#   'disk-usage': 2.0915149811213505,
#   'display': 3.295634963777275,
#   'downloads': 0.6020599913279624,
#   'drive': 0.9118639112994488,
#   'drivers': 0.6989700043360189,
#   'dvd': 2.0969100130080567,
#   'facebook': 3.9030899869919438,
#   'flash': 2.4717262228329564,
#   'free': 2.4082399653118496,
#   'google': 3.9030899869919438,
#   'graphics': 8.0,
#   'hardware': 1.806179973983887,
#   'hosting': 1.0,
#   'installation': 2.662184995396277,
#   'intel': 2.4717262228329564,
#   'internet': 2.4082399653118496,
#   'iso': 0.8239087409443188,
#   'less': 2.6020599913279625,
#   'libraries': 1.0,
#   'libreoffice': 5.204119982655925,
#   'lubuntu': 1.0,
#   'maintenance': 3.9030899869919438,
#   'media': 2.0969100130080567,
#   'monitor': 2.6020599913279625,
#   'more': 1.040362458673969,
#   'ram': 11.88249007371232,
#   'release-management': 1.6478174818886375,
#   'repository': 1.0457574905606752,
#   'reset': 1.0,
#   'security': 2.7958800173440754,
#   'server': 4.892790030352132,
#   'services': 3.9030899869919438,
#   'storage': 2.6020599913279625,
#   'support': 0.6020599913279624,
#   'system': 2.2450397202857335,
#   'ubuntu': 2.2488972589493987,
#   'ubuntu-minimal': 6.505149978319906,
#   'unity': 1.6478174818886375,
#   'updates': 2.1072099696478683,
#   'usb': 0.7789119315172683,
#   'versions': 3.8146623484712197,
#   'video': 1.6478174818886375,
#   'who': 0.6989700043360189,
#   'xubuntu': 4.0,
#   'youtube': 3.9030899869919438},
#  'How do I install Ubuntu alongside a pre-installed Windows with UEFI?': {'12.04': 4.943452445665913,
#   '12.10': 1.6478174818886375,
#   '15.04': 3.0,
#   '15.10': 2.6020599913279625,
#   '16.04': 1.6478174818886375,
#   '17.04': 1.3010299956639813,
#   '32-bit': 1.6478174818886375,
#   '64-bit': 4.193820026016113,
#   'acer': 2.0,
#   'add-apt-repository': 0.8239087409443188,
#   'alternative': 2.0,
#   'apt': 0.6020599913279624,
#   'binary': 2.6020599913279625,
#   'bios': 3.6601512169623636,
#   'boot': 15.529412473144948,
#   'boot-repair': 2.4717262228329564,
#   'bootloader': 2.4717262228329564,
#   'bug-reporting': 1.3010299956639813,
#   'button': 0.4559319556497244,
#   'can': 3.9288195105000336,
#   'command-line': 1.6837797902143001,
#   'compatibility': 2.6020599913279625,
#   'configure': 1.6478174818886375,
#   'copy': 0.6989700043360189,
#   'csm': 1.0,
#   'default': 0.9118639112994488,
#   'delete': 1.0,
#   'dell': 1.0,
#   'disk': 1.0457574905606752,
#   'disk-usage': 2.614393726401688,
#   'drive': 1.8237278225988975,
#   'dual-boot': 1.3010299956639813,
#   'echo': 1.6478174818886375,
#   'elementary': 1.3010299956639813,
#   'etc': 0.6020599913279624,
#   'ext4': 1.0,
#   'files': 1.5578238630345367,
#   'find': 1.989700043360188,
#   'firmware': 2.4717262228329564,
#   'free': 2.4082399653118496,
#   'fstab': 1.0,
#   'golang': 1.3677958669491732,
#   'gpt': 3.9030899869919438,
#   'grub-efi': 1.0,
#   'grub2': 9.086610056368245,
#   'hardware': 0.6020599913279624,
#   'hp': 3.0,
#   'installation': 10.648739981585107,
#   'intel': 0.8239087409443188,
#   'keys': 0.6020599913279624,
#   'launchpad': 2.0,
#   'layout': 1.0,
#   'lenovo': 4.0,
#   'live-cd': 2.7958800173440754,
#   'livedvd': 2.6020599913279625,
#   'make': 1.3871499448986253,
#   'menu': 5.228787452803376,
#   'microsoft': 3.0,
#   'mode': 4.559319556497244,
#   'more': 1.7339374311232816,
#   'motherboard': 3.0,
#   'mount': 0.6020599913279624,
#   'ms-dos': 3.9030899869919438,
#   'package-management': 0.6020599913279624,
#   'panel': 0.8239087409443188,
#   'partitioning': 9.118639112994488,
#   'partitions': 5.0152515121469685,
#   'permissions': 2.0,
#   'power-management': 1.806179973983887,
#   'process': 0.8239087409443188,
#   'ram': 1.3979400086720377,
#   'reboot': 0.7958800173440752,
#   'removing': 1.0,
#   'restart': 1.3979400086720377,
#   'root': 0.5228787452803376,
#   'scheme': 4.0,
#   'security': 0.6989700043360189,
#   'settings': 0.5228787452803376,
#   'shutdown': 4.0,
#   'snapshot': 2.6020599913279625,
#   'sony': 1.0,
#   'sudo': 1.040362458673969,
#   'support': 2.4082399653118496,
#   'swap': 2.0,
#   'system': 4.1159061538571775,
#   'testing': 2.0,
#   'time': 1.193820026016113,
#   'top': 0.6989700043360189,
#   'toshiba': 1.0,
#   'ubuntu': 10.244976401880594,
#   'uefi': 24.082399653118497,
#   'uninstall': 1.193820026016113,
#   'updates': 0.3010299956639812,
#   'upgrade': 0.6020599913279624,
#   'usb': 0.2596373105057561,
#   'users': 0.9118639112994488,
#   'versions': 2.7742998897972506,
#   'via': 1.6478174818886375,
#   'virtual': 1.3010299956639813,
#   'who': 0.6989700043360189,
#   'window': 0.6020599913279624,
#   'windows': 35.10676058502878,
#   'wireless': 0.8239087409443188,
#   'wubi': 5.204119982655925},
#  'How do I install Ubuntu?': {'14.04': 0.6989700043360189,
#   'adobe': 2.6020599913279625,
#   'apt': 0.9030899869919435,
#   'avi': 1.3010299956639813,
#   'backup': 1.0,
#   'bios': 2.0915149811213505,
#   'boot': 3.993277493094415,
#   'bootloader': 0.8239087409443188,
#   'burning': 2.6020599913279625,
#   'button': 0.4559319556497244,
#   'can': 0.7483465734285778,
#   'cd': 0.6935749724493127,
#   'codecs': 2.6020599913279625,
#   'command-line': 0.7483465734285778,
#   'configuration': 0.5228787452803376,
#   'connection': 1.6478174818886375,
#   'copy': 0.6989700043360189,
#   'cp': 2.0,
#   'default': 0.4559319556497244,
#   'detect': 0.8239087409443188,
#   'devices': 0.8239087409443188,
#   'directory': 0.6020599913279624,
#   'disk': 4.183029962242701,
#   'disk-usage': 0.5228787452803376,
#   'display': 1.6478174818886375,
#   'documentation': 0.8239087409443188,
#   'downloads': 1.2041199826559248,
#   'drive': 1.3677958669491732,
#   'dvd': 3.494850021680094,
#   'echo': 1.6478174818886375,
#   'files': 3.1156477260690734,
#   'find': 0.7958800173440752,
#   'flash': 1.6478174818886375,
#   'fonts': 1.3010299956639813,
#   'golang': 0.4559319556497244,
#   'hp': 1.0,
#   'icons': 0.8239087409443188,
#   'installation': 3.1058824946289896,
#   'internet': 1.2041199826559248,
#   'iso': 1.6478174818886375,
#   'keyboard': 2.0,
#   'keys': 1.2041199826559248,
#   'language': 2.6020599913279625,
#   'layout': 2.0,
#   'location': 1.0,
#   'login': 0.8239087409443188,
#   'make': 0.6935749724493127,
#   'menu': 2.614393726401688,
#   'microsoft': 1.0,
#   'more': 0.6935749724493127,
#   'motherboard': 1.0,
#   'mp3': 1.3010299956639813,
#   'mv': 1.3010299956639813,
#   'optical': 2.6020599913279625,
#   'package-management': 0.6020599913279624,
#   'partitioning': 2.279659778248622,
#   'password': 2.0969100130080567,
#   'plymouth': 1.0,
#   'prompt': 0.6989700043360189,
#   'proprietary': 2.0,
#   'reboot': 0.7958800173440752,
#   'restricted': 1.3010299956639813,
#   'safely': 1.3010299956639813,
#   'screen': 2.0915149811213505,
#   'sony': 1.0,
#   'source': 0.6989700043360189,
#   'startup': 0.8239087409443188,
#   'sudo': 1.3871499448986253,
#   'system': 0.9354332167857222,
#   'time': 1.193820026016113,
#   'toshiba': 1.0,
#   'ubuntu': 1.3743261026912992,
#   'ubuntu-restricted-extras': 1.3010299956639813,
#   'uefi': 1.806179973983887,
#   'uninstall': 0.3979400086720376,
#   'updates': 0.6020599913279624,
#   'upgrade': 0.6020599913279624,
#   'usb': 1.0385492420230245,
#   'username': 2.0,
#   'users': 0.4559319556497244,
#   'versions': 1.040362458673969,
#   'video': 0.8239087409443188,
#   'virtualbox': 1.3010299956639813,
#   'windows': 1.3677958669491732},
#  'How do I recover my accidentally lost Windows partitions after installing Ubuntu?': {'13.04': 1.0,
#   'apt': 0.9030899869919435,
#   'backup': 1.0,
#   'boot': 0.2218487496163564,
#   'cache': 1.3010299956639813,
#   'can': 1.1225198601428668,
#   'cd': 0.3467874862246563,
#   'command-line': 0.5612599300714334,
#   'copy': 2.0969100130080567,
#   'cp': 1.0,
#   'data-recovery': 1.6478174818886375,
#   'directory': 1.806179973983887,
#   'disk-usage': 1.0457574905606752,
#   'drive': 7.29491129039559,
#   'environment': 1.3010299956639813,
#   'files': 1.2981865525287806,
#   'free': 0.6020599913279624,
#   'installation': 0.8873949984654256,
#   'live-cd': 0.6989700043360189,
#   'make': 0.3467874862246563,
#   'media': 1.3979400086720377,
#   'menu': 0.5228787452803376,
#   'more': 1.040362458673969,
#   'mount': 1.2041199826559248,
#   'nautilus': 4.0,
#   'partitioning': 0.9118639112994488,
#   'partitions': 3.1915236895480708,
#   'paste': 1.3010299956639813,
#   'photorec': 1.3010299956639813,
#   'repository': 0.5228787452803376,
#   'session': 1.6478174818886375,
#   'sudo': 1.040362458673969,
#   'system': 0.3741732867142889,
#   'testdisk': 3.9030899869919438,
#   'time': 0.3979400086720376,
#   'ubuntu': 0.6246936830414996,
#   'umount': 1.3010299956639813,
#   'unmount': 1.3010299956639813,
#   'updates': 0.3010299956639812,
#   'usb': 1.0385492420230245,
#   'window': 0.6020599913279624,
#   'windows': 1.3677958669491732,
#   'windows-vista': 1.3010299956639813},
#  'How do I report a bug?': {'more': 0.3467874862246563,
#   'ubuntu': 0.12493873660829993,
#   'window': 0.6020599913279624},
#  'How do I reset a lost administrative password?': {'bios': 0.5228787452803376,
#   'boot': 0.4436974992327128,
#   'can': 0.7483465734285778,
#   'command-line': 0.18708664335714445,
#   'data-recovery': 1.6478174818886375,
#   'default': 0.4559319556497244,
#   'filesystem': 0.8239087409443188,
#   'log': 0.8239087409443188,
#   'menu': 0.5228787452803376,
#   'mode': 0.9118639112994488,
#   'mount': 0.6020599913279624,
#   'passwd': 2.6020599913279625,
#   'password': 7.688670047696207,
#   'permissions': 1.0,
#   'prompt': 1.3979400086720377,
#   'read-only': 1.0,
#   'reboot': 0.3979400086720376,
#   'reset': 1.0,
#   'root': 2.0915149811213505,
#   'screen': 0.5228787452803376,
#   'security': 1.3979400086720377,
#   'top': 0.6989700043360189,
#   'unix': 2.6020599913279625,
#   'username': 1.0,
#   'vulnerability': 1.3010299956639813,
#   'who': 0.6989700043360189},
#  'How do I resolve unmet dependencies after adding a PPA?': {'add-apt-repository': 1.6478174818886375,
#   'apt': 3.010299956639812,
#   'aptitude': 1.0,
#   'archive': 0.8239087409443188,
#   'can': 1.8708664335714444,
#   'cd': 1.040362458673969,
#   'command-line': 2.619213007000022,
#   'configuration': 0.5228787452803376,
#   'database': 1.3010299956639813,
#   'date': 1.0,
#   'debian': 1.3010299956639813,
#   'delete': 2.0,
#   'dependencies': 8.0,
#   'downloads': 0.6020599913279624,
#   'dpkg': 3.0,
#   'duplicate': 2.6020599913279625,
#   'files': 0.5192746210115122,
#   'find': 0.3979400086720376,
#   'https': 6.0,
#   'installation': 2.218487496163564,
#   'make': 0.6935749724493127,
#   'mkdir': 3.9030899869919438,
#   'more': 0.3467874862246563,
#   'output': 1.3010299956639813,
#   'package-management': 15.653559774527022,
#   'panel': 0.8239087409443188,
#   'ppa': 20.0,
#   'purge': 3.0,
#   'removing': 2.0,
#   'repository': 6.274544943364051,
#   'software-sources': 0.8239087409443188,
#   'source': 1.3979400086720377,
#   'su': 1.3010299956639813,
#   'sudo': 4.161449834695876,
#   'system': 0.3741732867142889,
#   'ubuntu': 1.4992648392995993,
#   'uninstall': 4.377340095392413,
#   'unity': 0.8239087409443188,
#   'updates': 1.806179973983887,
#   'upgrade': 3.010299956639812,
#   'versions': 1.040362458673969,
#   'wget': 8.0},
#  'How to install software or upgrade from an old unsupported release?': {'11.04': 1.3010299956639813,
#   '11.10': 1.0,
#   '13.04': 1.0,
#   'apt': 1.505149978319906,
#   'archive': 0.8239087409443188,
#   'cpu': 1.0,
#   'do-release-upgrade': 1.3010299956639813,
#   'etc': 0.6020599913279624,
#   'installation': 0.2218487496163564,
#   'lubuntu': 1.0,
#   'mirrors': 1.3010299956639813,
#   'ram': 0.6989700043360189,
#   'reinstall': 0.8239087409443188,
#   'release-management': 1.6478174818886375,
#   'repository': 1.0457574905606752,
#   'security': 0.6989700043360189,
#   'sed': 1.3010299956639813,
#   'server': 0.6989700043360189,
#   'software-sources': 0.8239087409443188,
#   'sudo': 2.080724917347938,
#   'support': 0.6020599913279624,
#   'system': 0.18708664335714445,
#   'updates': 1.505149978319906,
#   'upgrade': 0.6020599913279624,
#   'xubuntu': 1.0},
#  'How to remove Ubuntu and put Windows back on?': {'add-apt-repository': 0.8239087409443188,
#   'apt': 0.6020599913279624,
#   'boot': 1.5529412473144948,
#   'boot-repair': 3.295634963777275,
#   'bootloader': 2.4717262228329564,
#   'button': 0.4559319556497244,
#   'can': 0.9354332167857222,
#   'cd': 0.6935749724493127,
#   'command-line': 0.3741732867142889,
#   'copy': 0.6989700043360189,
#   'data-recovery': 4.943452445665913,
#   'dell': 6.0,
#   'disk': 0.5228787452803376,
#   'disk-usage': 1.0457574905606752,
#   'downloads': 1.2041199826559248,
#   'drive': 0.4559319556497244,
#   'dvd': 2.7958800173440754,
#   'files': 0.5192746210115122,
#   'free': 0.6020599913279624,
#   'golang': 0.9118639112994488,
#   'grub2': 0.6989700043360189,
#   'inspiron': 2.6020599913279625,
#   'installation': 1.7747899969308512,
#   'iso': 1.6478174818886375,
#   'laptop': 0.8239087409443188,
#   'logo': 1.3010299956639813,
#   'make': 0.3467874862246563,
#   'media': 2.7958800173440754,
#   'partitioning': 1.3677958669491732,
#   'partitions': 1.8237278225988975,
#   'prompt': 1.3979400086720377,
#   'reboot': 0.3979400086720376,
#   'screen': 1.0457574905606752,
#   'search': 0.6989700043360189,
#   'settings': 1.5686362358410129,
#   'sudo': 1.040362458673969,
#   'system': 0.3741732867142889,
#   'time': 0.3979400086720376,
#   'ubuntu': 1.2493873660829993,
#   'uefi': 1.806179973983887,
#   'unallocated': 1.3010299956639813,
#   'uninstall': 1.989700043360188,
#   'unity-dash': 1.3010299956639813,
#   'updates': 0.3010299956639812,
#   'usb': 0.2596373105057561,
#   'windows': 6.838979334745866},
#  'How to resize partitions?': {'apt': 0.3010299956639812,
#   'boot': 0.2218487496163564,
#   'can': 0.3741732867142889,
#   'cd': 0.3467874862246563,
#   'default': 0.4559319556497244,
#   'drive': 0.4559319556497244,
#   'golang': 0.4559319556497244,
#   'gparted': 1.3010299956639813,
#   'live-cd': 0.6989700043360189,
#   'mode': 0.4559319556497244,
#   'partitions': 0.4559319556497244,
#   'power-management': 0.6020599913279624,
#   'reboot': 0.3979400086720376,
#   'resize': 2.6020599913279625,
#   'usb': 0.2596373105057561},
#  'How to use manual partitioning during installation?': {'bios': 0.5228787452803376,
#   'boot': 1.109243748081782,
#   'can': 0.9354332167857222,
#   'cd': 0.3467874862246563,
#   'command-line': 0.18708664335714445,
#   'configuration': 0.5228787452803376,
#   'default': 0.4559319556497244,
#   'directory': 1.2041199826559248,
#   'disk': 4.705908707523038,
#   'disk-usage': 0.5228787452803376,
#   'ext4': 1.0,
#   'files': 1.0385492420230245,
#   'filesystem': 1.6478174818886375,
#   'free': 0.6020599913279624,
#   'images': 1.3010299956639813,
#   'installation': 1.109243748081782,
#   'kernel': 0.6020599913279624,
#   'libraries': 1.0,
#   'logs': 1.3010299956639813,
#   'mbr': 1.3010299956639813,
#   'media': 0.6989700043360189,
#   'more': 1.3871499448986253,
#   'music': 1.3010299956639813,
#   'partitioning': 4.10338760084752,
#   'partitions': 0.4559319556497244,
#   'raid': 3.9030899869919438,
#   'ram': 1.3979400086720377,
#   'reiserfs': 1.3010299956639813,
#   'root': 1.5686362358410129,
#   'scheme': 1.0,
#   'swap': 4.0,
#   'system': 0.7483465734285778,
#   'ubuntu': 0.12493873660829993,
#   'usb': 0.2596373105057561,
#   'users': 0.4559319556497244,
#   'windows': 0.9118639112994488},
#  'Installing Broadcom Wireless Drivers': {'12.04': 1.6478174818886375,
#   '12.10': 0.8239087409443188,
#   '13.10': 1.3010299956639813,
#   '14.04': 0.6989700043360189,
#   '16.04': 2.4717262228329564,
#   '32-bit': 1.6478174818886375,
#   '64-bit': 1.3979400086720377,
#   'adapter': 1.6478174818886375,
#   'alternative': 1.0,
#   'apt': 2.4082399653118496,
#   'aptitude': 1.0,
#   'architecture': 2.0,
#   'b43': 6.505149978319906,
#   'background': 1.3010299956639813,
#   'bios': 1.0457574905606752,
#   'boot': 1.3310924976981384,
#   'broadcasting': 1.3010299956639813,
#   'broadcom': 13.0,
#   'button': 0.4559319556497244,
#   'can': 1.8708664335714444,
#   'command-line': 1.8708664335714444,
#   'compiling': 1.0,
#   'configuration': 1.5686362358410129,
#   'configure': 1.6478174818886375,
#   'connection': 9.062996150387507,
#   'crash': 1.0,
#   'deb': 1.0,
#   'debugging': 1.3010299956639813,
#   'dependencies': 4.0,
#   'detect': 0.8239087409443188,
#   'devices': 4.943452445665913,
#   'directory': 2.4082399653118496,
#   'dkms': 1.3010299956639813,
#   'dmesg': 1.0,
#   'documentation': 0.8239087409443188,
#   'downloads': 1.2041199826559248,
#   'dpkg': 1.0,
#   'drivers': 16.775280104064453,
#   'ethernet': 1.0,
#   'files': 1.0385492420230245,
#   'find': 1.193820026016113,
#   'firmware': 0.8239087409443188,
#   'format': 1.3010299956639813,
#   'golang': 2.7355917338983464,
#   'gui': 1.0,
#   'hardware': 0.6020599913279624,
#   'icons': 0.8239087409443188,
#   'installation': 5.989916239641623,
#   'internet': 2.4082399653118496,
#   'ipv6': 1.0,
#   'irc': 1.3010299956639813,
#   'kernel': 1.2041199826559248,
#   'laptop': 0.8239087409443188,
#   'launchpad': 1.0,
#   'lenovo': 2.0,
#   'log': 1.6478174818886375,
#   'lspci': 1.0,
#   'lts': 1.0,
#   'mac': 2.0,
#   'make': 1.040362458673969,
#   'mode': 1.8237278225988975,
#   'modem': 1.3010299956639813,
#   'modprobe': 3.0,
#   'more': 1.3871499448986253,
#   'networking': 9.0,
#   'nvidia': 1.0,
#   'offline': 2.6020599913279625,
#   'package-management': 13.245319809215173,
#   'panel': 0.8239087409443188,
#   'password': 0.6989700043360189,
#   'power-management': 0.6020599913279624,
#   'purge': 2.0,
#   'reboot': 1.193820026016113,
#   'reinstall': 0.8239087409443188,
#   'repository': 0.5228787452803376,
#   'rev': 17.0,
#   'rfkill': 2.0,
#   'router': 10.40823996531185,
#   'search': 2.0969100130080567,
#   'sharing': 1.3010299956639813,
#   'signal': 2.4717262228329564,
#   'source': 0.6989700043360189,
#   'sudo': 4.508237320920532,
#   'support': 1.2041199826559248,
#   'synaptic': 1.3010299956639813,
#   'system': 1.4966931468571556,
#   'testing': 1.0,
#   'time': 1.193820026016113,
#   'timeout': 1.3010299956639813,
#   'top': 0.6989700043360189,
#   'traffic': 1.3010299956639813,
#   'ubuntu': 1.2493873660829993,
#   'uninstall': 1.193820026016113,
#   'updates': 0.6020599913279624,
#   'upgrade': 0.6020599913279624,
#   'usb': 0.2596373105057561,
#   'users': 1.3677958669491732,
#   'versions': 2.427512403572594,
#   'via': 1.6478174818886375,
#   'who': 1.3979400086720377,
#   'window': 0.6020599913279624,
#   'wired': 1.0,
#   'wireless': 27.18898845116252,
#   'xorg': 1.3010299956639813},
#  'My computer boots to a black screen what options do I have to fix it?': {'12.04': 0.8239087409443188,
#   '12.10': 0.8239087409443188,
#   'ahci': 1.3010299956639813,
#   'amd-graphics': 1.3010299956639813,
#   'backlight': 1.3010299956639813,
#   'bios': 2.0915149811213505,
#   'boot': 2.662184995396277,
#   'boot-repair': 0.8239087409443188,
#   'can': 0.7483465734285778,
#   'cd': 0.6935749724493127,
#   'community': 4.0,
#   'configure': 0.8239087409443188,
#   'csm': 2.0,
#   'documentation': 3.295634963777275,
#   'drive': 0.4559319556497244,
#   'drivers': 2.7958800173440754,
#   'dvd': 1.3979400086720377,
#   'encryption': 2.0,
#   'files': 0.5192746210115122,
#   'find': 0.7958800173440752,
#   'firmware': 2.4717262228329564,
#   'flash': 0.8239087409443188,
#   'golang': 0.4559319556497244,
#   'graphics': 5.0,
#   'grub-efi': 1.0,
#   'grub2': 2.7958800173440754,
#   'hardware': 1.2041199826559248,
#   'hybrid': 1.3010299956639813,
#   'ie': 1.0,
#   'installation': 3.5495799938617023,
#   'internet': 0.6020599913279624,
#   'kernel': 1.2041199826559248,
#   'keyboard': 1.0,
#   'keys': 1.806179973983887,
#   'laptop': 0.8239087409443188,
#   'live-cd': 1.3979400086720377,
#   'login-screen': 1.3010299956639813,
#   'luks': 1.3010299956639813,
#   'lvm': 1.0,
#   'make': 0.3467874862246563,
#   'menu': 0.5228787452803376,
#   'mode': 1.8237278225988975,
#   'more': 0.3467874862246563,
#   'nvidia': 3.0,
#   'password': 1.3979400086720377,
#   'proprietary': 1.0,
#   'reboot': 0.3979400086720376,
#   'restart': 0.6989700043360189,
#   'sata': 1.3010299956639813,
#   'screen': 4.705908707523038,
#   'search': 0.6989700043360189,
#   'settings': 2.0915149811213505,
#   'startup': 0.8239087409443188,
#   'system': 0.3741732867142889,
#   'text': 1.0,
#   'time': 0.7958800173440752,
#   'tty': 1.0,
#   'ubuntu': 1.999019785732799,
#   'uefi': 11.439139835231286,
#   'usb': 0.5192746210115122,
#   'users': 0.4559319556497244},
#  'My wireless/WiFi connection does not work. What information is needed to diagnose the issue?': {'14.04': 2.0969100130080567,
#   '64-bit': 2.0969100130080567,
#   'acer': 1.0,
#   'adapter': 0.8239087409443188,
#   'alias': 10.40823996531185,
#   'archive': 0.8239087409443188,
#   'ath9k': 13.010299956639813,
#   'atheros': 11.709269960975831,
#   'authentication': 6.505149978319906,
#   'blacklist': 22.11750992628768,
#   'broadcom': 1.0,
#   'bsd': 5.204119982655925,
#   'chmod': 1.3010299956639813,
#   'compiz': 1.0,
#   'configuration': 0.5228787452803376,
#   'connection': 0.8239087409443188,
#   'default': 4.559319556497244,
#   'detect': 0.8239087409443188,
#   'dmesg': 1.0,
#   'dns': 1.3010299956639813,
#   'drivers': 10.484550065040283,
#   'echo': 6.59126992755455,
#   'encryption': 10.0,
#   'etc': 14.449439791871097,
#   'ethernet': 2.0,
#   'filename': 7.8061799739838875,
#   'files': 0.5192746210115122,
#   'frequency': 2.6020599913279625,
#   'gateway': 2.6020599913279625,
#   'gnome': 1.3010299956639813,
#   'gnu': 1.3010299956639813,
#   'gpl': 7.8061799739838875,
#   'grep': 1.0,
#   'hardware': 0.6020599913279624,
#   'hotplug': 1.3010299956639813,
#   'https': 1.0,
#   'ie': 5.0,
#   'ifconfig': 1.3010299956639813,
#   'info': 5.204119982655925,
#   'integrated': 2.6020599913279625,
#   'intel': 1.6478174818886375,
#   'interface': 2.6020599913279625,
#   'internet': 1.2041199826559248,
#   'ip': 1.3010299956639813,
#   'ipv4': 1.3010299956639813,
#   'ipv6': 2.0,
#   'iwlwifi': 1.3010299956639813,
#   'kernel': 6.020599913279624,
#   'keys': 0.6020599913279624,
#   'lan': 7.8061799739838875,
#   'license': 7.8061799739838875,
#   'location': 1.0,
#   'lspci': 1.0,
#   'lsusb': 1.3010299956639813,
#   'lts': 1.0,
#   'mac': 1.0,
#   'modprobe': 2.0,
#   'netgear': 1.3010299956639813,
#   'networking': 2.0,
#   'pci': 2.6020599913279625,
#   'pcie': 1.3010299956639813,
#   'plymouth': 1.0,
#   'pm-utils': 22.11750992628768,
#   'power-management': 0.6020599913279624,
#   'release-management': 1.6478174818886375,
#   'resolv.conf': 1.3010299956639813,
#   'rev': 2.0,
#   'rfkill': 1.0,
#   'root': 5.751666198083714,
#   'routing': 1.3010299956639813,
#   'rtc': 1.3010299956639813,
#   'scripts': 2.6020599913279625,
#   'settings': 1.0457574905606752,
#   'signal': 5.7673611866102314,
#   'support': 3.612359947967774,
#   'system': 0.3741732867142889,
#   'time': 0.3979400086720376,
#   'tlp': 20.8164799306237,
#   'ubuntu': 0.3748162098248998,
#   'udev': 2.6020599913279625,
#   'uninstall': 0.3979400086720376,
#   'usb': 0.5192746210115122,
#   'versions': 1.7339374311232816,
#   'via': 0.8239087409443188,
#   'video': 0.8239087409443188,
#   'wget': 1.0,
#   'wired': 3.0,
#   'wireless': 18.949901041719333,
#   'wpa': 7.8061799739838875,
#   'wpa2': 19.51544993495972,
#   'xargs': 1.3010299956639813},
#  'Ubuntu gets stuck in a login loop': {'login': 0.8239087409443188,
#   'restart': 0.6989700043360189,
#   'root': 2.0915149811213505,
#   'screen': 0.5228787452803376,
#   'tmp': 1.3010299956639813},
#  'Unable to mount Windows (NTFS) filesystem due to hibernation': {'boot': 1.7747899969308512,
#   'browser': 1.3010299956639813,
#   'button': 0.4559319556497244,
#   'command-line': 0.9354332167857222,
#   'crash': 1.0,
#   'default': 1.8237278225988975,
#   'dialog': 2.0,
#   'directory': 2.4082399653118496,
#   'disk': 0.5228787452803376,
#   'files': 1.5578238630345367,
#   'filesystem': 0.8239087409443188,
#   'hibernate': 1.3010299956639813,
#   'icons': 0.8239087409443188,
#   'input': 1.3010299956639813,
#   'make': 0.3467874862246563,
#   'menu': 0.5228787452803376,
#   'mode': 3.1915236895480708,
#   'mount': 6.622659904607587,
#   'mountpoint': 1.3010299956639813,
#   'nautilus': 3.0,
#   'ntfs': 1.3010299956639813,
#   'partitioning': 5.0152515121469685,
#   'partitions': 0.9118639112994488,
#   'power-management': 1.2041199826559248,
#   'process': 0.8239087409443188,
#   'prompt': 0.6989700043360189,
#   'read-only': 2.0,
#   'resume': 3.9030899869919438,
#   'session': 1.6478174818886375,
#   'settings': 0.5228787452803376,
#   'shortcuts': 1.3010299956639813,
#   'shutdown': 4.0,
#   'startup': 1.6478174818886375,
#   'system': 0.3741732867142889,
#   'time': 0.3979400086720376,
#   'ubuntu': 0.3748162098248998,
#   'uninstall': 0.3979400086720376,
#   'versions': 0.3467874862246563,
#   'windows': 11.854230846892834},
#  "Unity doesn't load no Launcher no Dash appears": {'18.04': 1.0,
#   'apt': 0.3010299956639812,
#   'can': 0.7483465734285778,
#   'ccsm': 1.3010299956639813,
#   'checkbox': 1.3010299956639813,
#   'command-line': 0.7483465734285778,
#   'compiz': 2.0,
#   'display': 0.8239087409443188,
#   'find': 0.3979400086720376,
#   'installation': 0.2218487496163564,
#   'log': 0.8239087409443188,
#   'opengl': 1.3010299956639813,
#   'plugins': 7.8061799739838875,
#   'restart': 0.6989700043360189,
#   'screenshot': 1.3010299956639813,
#   'search': 1.3979400086720377,
#   'server': 0.6989700043360189,
#   'settings': 0.5228787452803376,
#   'sudo': 0.3467874862246563,
#   'tty': 1.0,
#   'ubuntu': 0.7496324196497997,
#   'unity': 5.7673611866102314,
#   'versions': 0.6935749724493127},
#  'What should I do when Ubuntu freezes?': {'button': 0.9118639112994488,
#   'can': 0.5612599300714334,
#   'cleanup': 1.3010299956639813,
#   'command-line': 0.18708664335714445,
#   'cursor': 1.3010299956639813,
#   'dialog': 1.0,
#   'gui': 1.0,
#   'kernel': 0.6020599913279624,
#   'keys': 0.6020599913279624,
#   'kill': 2.6020599913279625,
#   'login': 0.8239087409443188,
#   'mouse': 3.9030899869919438,
#   'process': 2.4717262228329564,
#   'screen': 0.5228787452803376,
#   'signal': 0.8239087409443188,
#   'top': 0.6989700043360189,
#   'window': 2.4082399653118496}}

# %%
new_path = 'C:\\Users\\gauth\\AnacondaProjects\\Stack ApiV1\\AllTagExtractionCodeV4\\tfIdf.txt'
tfIdfFile = open(new_path,'w')
tfIdfFile.write(str(tagTfIdf))
tfIdfFile.close()
